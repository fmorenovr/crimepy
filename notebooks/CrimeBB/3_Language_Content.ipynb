# %%
import pandas as pd
import sys, os

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from crimebb import *

# %%
from tqdm.notebook import tqdm

tqdm.pandas()

# %%
# !pip install pyenchant

# %%
# !pip install nltk

# %%
# !pip install wordcloud

# %%
# !pip install pycountry

# %%
# !pip install multidict

# %%
YEAR="2021"

# %%
DATA_PATH="../../data/"
CSV_PATH = f"{DATA_PATH}csv/{YEAR}/summary/"
CSV_PROCESSED = f"{DATA_PATH}csv/{YEAR}/processed/"

# %% [markdown]
# ### Loading data

# %% [markdown]
# #### boards

# %%
boards_df = pd.read_csv(f"{CSV_PATH}boards.csv", sep="\t", low_memory=False)
boards_df["url"] = boards_df["url"].apply(lambda x: x.replace("antichat.com", "forum.antichat.ru"))
boards_df["site_name"] = boards_df["url"].apply(lambda x: (x.replace("https://", "")).split("/")[0] if "https" in x else (x.replace("http://", "")).split("/")[0] )
boards_df.drop_duplicates(inplace=True)
boards_df = boards_df[["id", "site_id", "site_name", "name", "url"]].copy().drop_duplicates()
boards_df.rename(columns={"id":"board_id", "name":"board_title", "url":"board_url"}, inplace=True)
boards_df
# Out:
#      board_id  site_id               site_name  \
# 0          24       10       forum.antichat.ru
# 1         145       10       forum.antichat.ru
# 2         150       10       forum.antichat.ru
# 3         157       10       forum.antichat.ru
# 4          30       10       forum.antichat.ru
# ..        ...      ...                     ...
# 893        32       20  torum6uvof666pzw.onion
# 894        24       20  torum6uvof666pzw.onion
# 895        29       20  torum6uvof666pzw.onion
# 896        60       20  torum6uvof666pzw.onion
# 897        26       20  torum6uvof666pzw.onion
#
#                                  board_title  \
# 0               С/С++, C#, Delphi, .NET, Asm
# 1                        Хостинги - Hostings
# 2    Мобильная связь, СМС - Покупка, продажа
# 3            Услуги, Покупка и Продажа в SEO
# 4                                     Статьи
# ..                                       ...
# 893                    Networking / Wireless
# 894                       Website Pentesting
# 895                        Operating Systems
# 896                               Challenges
# 897                        Denial of Service
#
#                                              board_url
# 0         https://forum.antichat.ru/forums/24/page-356
# 1    https://forum.antichat.ru/forumdisplay.php?f=1...
# 2        https://forum.antichat.ru/forums/150/page-266
# 3     https://forum.antichat.ru/link-forums/157/page-2
# 4    https://forum.antichat.ru/forumdisplay.php?f=3...
# ..                                                 ...
# 893  http://torum6uvof666pzw.onion/viewforum.php?f=...
# 894  http://torum6uvof666pzw.onion/viewforum.php?f=...
# 895  http://torum6uvof666pzw.onion/viewforum.php?f=...
# 896  http://torum6uvof666pzw.onion/viewforum.php?f=...
# 897  http://torum6uvof666pzw.onion/viewforum.php?f=...
#
# [898 rows x 5 columns]

# %% [markdown]
# #### website

# %%
website_df = boards_df[["site_name", "site_id"]].copy()
website_df.drop_duplicates(inplace=True)
website_df
# Out:
#                   site_name  site_id
# 0         forum.antichat.ru       10
# 64   germanyruvvy2tcw.onion       23
# 107  dreadditevelidot.onion       19
# 553  envoys5appps3bin.onion       21
# 646      garage4hackers.com        7
# 681          raidforums.com       12
# 756  lwplxqzvmgu43uff.onion       24
# 775    www.safeskyhacks.com       13
# 825  thehub7xbw4dc5r2.onion        2
# 887  torum6uvof666pzw.onion       20

# %% [markdown]
# #### Threads

# %%
threads_df = pd.read_csv(f"{CSV_PATH}threads.csv", sep="\t", low_memory=False)
threads_df["url"] = threads_df["url"].apply(lambda x: x.replace("antichat.com", "forum.antichat.ru"))
threads_df.drop_duplicates(inplace=True)
threads_df = threads_df[["id", "site_id", "board_id", "creator", "creator_id", "name", "url", "created_on"]].copy().drop_duplicates()
threads_df.rename(columns={"creator":"username", "id":"thread_id", "creator_id":"user_id", "name":"thread_title", "url":"thread_url", "created_on": "thread_data_creation"}, inplace=True)
#threads_df = threads_df[ (threads_df["username"].str.lower()!="none")] ].copy().drop_duplicates()
#threads_df = threads_df[ (~threads_df["username"].isna()) ].copy().drop_duplicates()
threads_df
# Out:
#         thread_id  site_id  board_id       username  user_id  \
# 0          473570       10        23        dbagrov   342815
# 1          472702       10        23    Dark_shadow   335846
# 2          473412       10        23   littlebig000   327300
# 3          472675       10        23      Alienplan   335505
# 4          473059       10        23      010101Hex   327986
# ...           ...      ...       ...            ...      ...
# 405178       4450       20        62   variable6754    11470
# 405179       4495       20        62  WrecklessRush    10707
# 405180       4182       20        62  8634534634543    10256
# 405181       3848       20        62           AXDZ     9220
# 405182       2571       20        62     D1sgruntl3     4266
#
#                                              thread_title  \
# 0       ФСБ видит угрозу в защищённых мессенджерах и а...
# 1       Эксперт Google: Вредоносные сайты атаковали по...
# 2               Ирак полностью отключил интернет в стране
# 3       [ВОЗМОЖНО] СОРМ расшифровывает HTTPS трафик к ...
# 4       Обвиняемый во взломе JP Morgan Chase россиянин...
# ...                                                   ...
# 405178                     Working dark net market places
# 405179                     Need Empire market mirror link
# 405180    Discovering A Legitimate Online Hacking Service
# 405181                                        best market
# 405182              DeepMart Market? is this place legit?
#
#                                                thread_url  \
# 0               https://forum.antichat.ru/threads/473570/
# 1               https://forum.antichat.ru/threads/472702/
# 2               https://forum.antichat.ru/threads/473412/
# 3               https://forum.antichat.ru/threads/472675/
# 4               https://forum.antichat.ru/threads/473059/
# ...                                                   ...
# 405178  http://torum6uvof666pzw.onion/viewtopic.php?f=...
# 405179  http://torum6uvof666pzw.onion/viewtopic.php?f=...
# 405180  http://torum6uvof666pzw.onion/viewtopic.php?f=...
# 405181  http://torum6uvof666pzw.onion/viewtopic.php?f=...
# 405182  http://torum6uvof666pzw.onion/viewtopic.php?f=...
#
#                  thread_data_creation
# 0       2019-10-24 12:09:03.149923-03
# 1       2019-10-24 12:09:29.163386-03
# 2       2019-10-24 12:09:05.359046-03
# 3        2019-10-24 12:09:29.64036-03
# 4       2019-10-24 12:09:18.955105-03
# ...                               ...
# 405178   2019-08-07 12:07:39.79638-03
# 405179  2019-08-07 12:07:16.971569-03
# 405180  2019-08-07 12:09:41.136812-03
# 405181  2019-08-07 12:09:52.858637-03
# 405182  2019-08-07 12:12:42.464312-03
#
# [405183 rows x 8 columns]

# %% [markdown]
# #### posts

# %%
posts_df = pd.read_csv(f"{CSV_PATH}posts.csv", sep="\t", low_memory=False)
posts_df.drop_duplicates(inplace=True)
posts_df = posts_df[["id", "site_id", "board_id", "thread_id", "creator", "creator_id", "creator_n_posts", "creator_reputation", "content", "quoted_post_ids", "created_on"]].copy().drop_duplicates()
posts_df.rename(columns={"creator":"username", "id":"post_id", "creator_id":"user_id", "creator_n_posts":"user_num_posts", "creator_reputation":"user_reputation", "created_on": "post_data_creation"}, inplace=True)
#posts_df = posts_df[ (posts_df["username"].str.lower()!="none") ].copy().drop_duplicates()
posts_df = posts_df[~posts_df["content"].isna()].copy().drop_duplicates()
posts_df
# Out:
#          post_id  site_id  board_id  thread_id          username  user_id  \
# 0             34       10       114          9             Algol     1174
# 1            637       10       114        113             Algol     1174
# 2            710       10       114        137             Algol     1174
# 3            491       10       114         99  GPT cd-r74xl 24x     1548
# 4            571       10        46        120             iRedX     1968
# ...          ...      ...       ...        ...               ...      ...
# 3373784    42116       20        49       8611        tolerance2    24965
# 3373785    42124       20        62       8454            mrkcuf    22583
# 3373786    42129       20        62       8454               rIA    15407
# 3373787    42134       20        62       8454       lovelycloud    25064
# 3373788    42135       20        62       8454       lovelycloud    25064
#
#          user_num_posts  user_reputation  \
# 0                  1761                0
# 1                  1761                0
# 2                  1761                0
# 3                     1                0
# 4                   123                9
# ...                 ...              ...
# 3373784              14                0
# 3373785              52                0
# 3373786              27                0
# 3373787               7                0
# 3373788               7                0
#
#                                                    content quoted_post_ids  \
# 0            Адрес хоть дай...Первый раз слышу о таком ...              {}
# 1                             Кстати этот чат ломается ...              {}
# 2        Чесно говоря это действительно большая редкост...              {}
# 3        Сорри, этт я неправильно указал ихний адрес. И...              {}
# 4                                   Скоро будет обновление              {}
# ...                                                    ...             ...
# 3373784  What is that? I dont have javascript enabled s...              {}
# 3373785  ***LINK***lovelycloud[./memberlist.php?mode=vi...              {}
# 3373786  I wrote some keyloggers for android if you are...              {}
# 3373787                                               ok..              {}
# 3373788  ***LINK***rIA[./memberlist.php?mode=viewprofil...              {}
#
#              post_data_creation
# 0        2002-05-31 06:36:00-03
# 1        2002-08-05 16:15:00-03
# 2        2002-08-12 08:08:00-03
# 3        2002-07-19 09:30:00-03
# 4        2002-07-31 23:01:00-03
# ...                         ...
# 3373784  2019-08-06 21:00:00-03
# 3373785  2019-08-06 21:00:00-03
# 3373786  2019-08-06 21:00:00-03
# 3373787  2019-08-06 21:00:00-03
# 3373788  2019-08-06 21:00:00-03
#
# [3369015 rows x 11 columns]

# %% [markdown]
# #### posts x threads x boards x website

# %%
posts_website_df = pd.merge(posts_df, website_df, how="left", on="site_id")

# %%
posts_boards_df = pd.merge(posts_website_df, boards_df[["site_id", "board_id", "board_title"]].drop_duplicates(), on=["site_id", "board_id"], how="left")

# %%
posts_threads_df = pd.merge(posts_boards_df, threads_df[["site_id", "board_id", "thread_id", "thread_title"]].drop_duplicates(), on=["site_id", "board_id", "thread_id"], how="left")
posts_threads_df = posts_threads_df[['post_id', 'site_id', 'board_id', 'thread_id', 'user_id', 
                                     'site_name', 'board_title', 'thread_title', 'username',
                                     'content', 'user_num_posts', 'user_reputation',
                                     'quoted_post_ids', 'post_data_creation']].copy()

# %%
posts_threads_df
# Out:
#          post_id  site_id  board_id  thread_id  user_id  \
# 0             34       10       114          9     1174
# 1            637       10       114        113     1174
# 2            710       10       114        137     1174
# 3            491       10       114         99     1548
# 4            571       10        46        120     1968
# ...          ...      ...       ...        ...      ...
# 3369010    42116       20        49       8611    24965
# 3369011    42124       20        62       8454    22583
# 3369012    42129       20        62       8454    15407
# 3369013    42134       20        62       8454    25064
# 3369014    42135       20        62       8454    25064
#
#                       site_name              board_title  \
# 0             forum.antichat.ru           Веб-уязвимости
# 1             forum.antichat.ru           Веб-уязвимости
# 2             forum.antichat.ru           Веб-уязвимости
# 3             forum.antichat.ru           Веб-уязвимости
# 4             forum.antichat.ru                 Болталка
# ...                         ...                      ...
# 3369010  torum6uvof666pzw.onion      General Discussions
# 3369011  torum6uvof666pzw.onion  Marketplace Discussions
# 3369012  torum6uvof666pzw.onion  Marketplace Discussions
# 3369013  torum6uvof666pzw.onion  Marketplace Discussions
# 3369014  torum6uvof666pzw.onion  Marketplace Discussions
#
#                                       thread_title          username  \
# 0                                    ВЗЛОМ ФОРУМОВ             Algol
# 1                         Есть вопрос на счёт чата             Algol
# 2                              Клиенты для чата...             Algol
# 3        Всевидящее Око на http://chat.userline.ru  GPT cd-r74xl 24x
# 4                                    Зацените сайт             iRedX
# ...                                            ...               ...
# 3369010                                 Free stuff        tolerance2
# 3369011                                  KEYLOGGER            mrkcuf
# 3369012                                  KEYLOGGER               rIA
# 3369013                                  KEYLOGGER       lovelycloud
# 3369014                                  KEYLOGGER       lovelycloud
#
#                                                    content  user_num_posts  \
# 0            Адрес хоть дай...Первый раз слышу о таком ...            1761
# 1                             Кстати этот чат ломается ...            1761
# 2        Чесно говоря это действительно большая редкост...            1761
# 3        Сорри, этт я неправильно указал ихний адрес. И...               1
# 4                                   Скоро будет обновление             123
# ...                                                    ...             ...
# 3369010  What is that? I dont have javascript enabled s...              14
# 3369011  ***LINK***lovelycloud[./memberlist.php?mode=vi...              52
# 3369012  I wrote some keyloggers for android if you are...              27
# 3369013                                               ok..               7
# 3369014  ***LINK***rIA[./memberlist.php?mode=viewprofil...               7
#
#          user_reputation quoted_post_ids      post_data_creation
# 0                      0              {}  2002-05-31 06:36:00-03
# 1                      0              {}  2002-08-05 16:15:00-03
# 2                      0              {}  2002-08-12 08:08:00-03
# 3                      0              {}  2002-07-19 09:30:00-03
# 4                      9              {}  2002-07-31 23:01:00-03
# ...                  ...             ...                     ...
# 3369010                0              {}  2019-08-06 21:00:00-03
# 3369011                0              {}  2019-08-06 21:00:00-03
# 3369012                0              {}  2019-08-06 21:00:00-03
# 3369013                0              {}  2019-08-06 21:00:00-03
# 3369014                0              {}  2019-08-06 21:00:00-03
#
# [3369015 rows x 14 columns]

# %%
posts_threads_df.to_csv(f"{CSV_PROCESSED}crimeBB_{YEAR}.csv", sep='\t', index=False)

# %%
os.exit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 os.exit()
#
# AttributeError: module 'os' has no attribute 'exit'

# %% [markdown]
# #### Detecting languages

# %%
language_to_eval = ["russian", "german", "english"]

# %%
if verifyFile(f"{CSV_PROCESSED}content_languages.csv"):
    content_df = pd.read_csv(f"{CSV_PROCESSED}content_languages.csv", sep="\t", low_memory=False)
    list_post = content_df[~content_df["language_detected"].isna()]["post_id"].values
else:
    content_df = posts_threads_df[["post_id", "content"]].copy()
    # content_df["content_processed"] = content_df["content"].apply(lambda x: re.sub('[\\\\\'\"+@_!#$%^&*,;().<>?/\|\[\]}{~:=\n]', " ", x) )
    # content_df["content_processed"] = content_df["content_processed"].apply(str.lower)
    content_df["lang_ratio"] = np.nan
    content_df["language_detected"] = np.nan
    content_df["lang_correct_words"] = np.nan
    content_df["len_correct_words"] = np.nan
    content_df["lang_incorrect_words"] = np.nan
    content_df["len_incorrect_words"] = np.nan
    list_post = []

# %%
os.exit()

# %%
count = 1
for index, row in tqdm(content_df.iterrows()):
    
    lang_ratio, lang_badwords, lang_goodwords = detect_language_and_words(row["content"], language_to_eval=language_to_eval)
    posts_threads_df.loc[index, "lang_ratio"] = [lang_ratio]
    lang_detected = max(lang_ratio, key=lang_ratio.get)
    content_df.loc[(d_manejo_key['TpRem'] == 'MANEJO'), "language_detected"] = lang_detected
    content_df.loc[index, "lang_correct_words"] = [{lang_detected: lang_goodwords[lang_detected]}]
    content_df.loc[index, "len_correct_words"] = len(set(lang_goodwords[lang_detected]))
    content_df.loc[index, "lang_incorrect_words"] = [{lang_detected: lang_badwords[lang_detected]}]
    content_df.loc[index, "len_incorrect_words"] = len(set(lang_badwords[lang_detected]))

    if count%10000==0: # grava cada 10 k muestras
        content_df.to_csv(f"{CSV_PROCESSED}content_languages.csv", sep='\t', index=False)
    
    count+=1

# %%
content_df.to_csv(f"{CSV_PROCESSED}content_languages.csv", sep='\t', index=False)

# %% [markdown]
# ### Languages

# %%
lang_post_df = content_df.pivot_table(columns=['language_detected'], aggfunc='size')
lang_post_df.sort_values(ascending=False, inplace=True)
lang_post_df

# %%
mean_val = round(lang_post_df.mean(), 2)

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(lang_post_df.index.values, lang_post_df.values)

for x,y,p in zip(lang_post_df.index.values, lang_post_df.values, lang_post_df.values):
  plt.text(x, y, p)
plt.xlabel("Languages detected")
plt.ylabel("Number of documents")
plt.title(f"Number of documents per language, Avg: {mean_val}")
plt.show()

# %% [markdown]
# #### Russian

# %%
# russian_df = content_df[content_df["language_detected"]=="russian"].copy()
# russian_df.info(), russian_df.shape, russian_df.iloc[0,:]

# %%
# russian_content = ' '.join(russian_df["content"])

# %%
# russian_dict = get_text_frequency(russian_content)
# len(russian_dict)

# %%
# showWordCloud(russian_dict, f"Russian-Wordcloud", max_words=int(len(russian_dict)))

# %% [markdown]
# #### English

# %%
# english_df = content_df[content_df["language_detected"]=="english"].copy()
# english_df.info(), english_df.shape, english_df.iloc[0,:]

# %%
# english_content = ' '.join(english_df["content"])

# %%
# english_dict = get_text_frequency(english_content)
# len(english_dict)

# %%
# showWordCloud(english_dict, f"English-Wordcloud", max_words=int(len(english_dict)))

# %% [markdown]
# #### German

# %%
# german_df = content_df[content_df["language_detected"]=="german"].copy()
# german_df.info(), german_df.shape, german_df.iloc[0,:]

# %%
# german_content = ' '.join(german_df["content"])

# %%
# german_dict = get_text_frequency(german_content)
# len(german_dict)

# %%
# showWordCloud(german_dict, f"German-Wordcloud", max_words=int(len(german_dict)))
