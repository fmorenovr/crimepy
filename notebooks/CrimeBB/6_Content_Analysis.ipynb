# %%
import pandas as pd
import re
import sys, os

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from crimebb import *

# %%
YEAR="2019"

# %%
DATA_PATH="../../data/"
CSV_PROCESSED = f"{DATA_PATH}csv/{YEAR}/processed/"

# %% [markdown]
# #### Words to look

# %% [markdown]
# ### Patterns to look

# %%
uri_reference = "^(?:([A-Za-z][A-Za-z0-9+\\-.]*):(?://((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|:)*@)?(?:\\[(?:(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?|[Vv][0-9A-Fa-f]+\\.(?:[!$&'()*+,;=A-Za-z0-9\\-._~]|:)+)\\]|(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])*)(?::[0-9]*)?)((?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|(/(?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)?)|((?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|())(?:\\?((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?(?:#((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?|(?://((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|:)*@)?(?:\\[(?:(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?|[Vv][0-9A-Fa-f]+\\.(?:[!$&'()*+,;=A-Za-z0-9\\-._~]|:)+)\\]|(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])*)(?::[0-9]*)?)((?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|(/(?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)?)|((?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|@)+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|())(?:\\?((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?(?:#((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?)$"

# %%
url_reference = "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"

# %%
urn_reference = "^(([^:/?#]+)?:)?(//([^/?#]*))?([^?#]*)(\?([^#]*))?(#(.*))?"
urn_reference = "^((?P<scheme>[^:/?#]+):(?=//))?(//)?(((?P<login>[^:]+)(?::(?P<password>[^@]+)?)?@)?(?P<host>[^@/?#:]*)(?::(?P<port>\d+)?)?)?(?P<path>[^?#]*)(\?(?P<query>[^#]*))?(#(?P<fragment>.*))?"
urn_reference = r'(?:http://|ftp://)?\w+\.\S*[^.\s]'

# %%
ipv4_address = '^(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])$'

# %%
ipv6_address = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)$'
ipv6_addrz = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+$'
ipv6_address_or_addrz = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?$'

# %% [markdown]
# ### Loading data

# %%
chunk_size = 1000000

crimeBB_reader = pd.read_csv(f"{CSV_PROCESSED}crimeBB_{YEAR}.csv", sep="\t", low_memory=False, iterator=True)
            
crimeBB_df = pd.DataFrame()

len_readed=chunk_size
while len_readed>=chunk_size:
    current_df = crimeBB_reader.get_chunk(chunk_size).copy()
    current_df.drop_duplicates(inplace=True)
    
    len_readed = current_df.shape[0]
    
    current_df = current_df[["post_id", "site_id", "board_id", "thread_id", "content"]].copy().drop_duplicates()
    
    current_df = current_df[~current_df["content"].isna()].copy().drop_duplicates()
    
    # URIS
    #current_df["uris"] = current_df["content"].apply(lambda x: re.findall(uri_reference, x.lower(), flags=re.IGNORECASE))
    #current_df["uris_len"] = current_df["uris_mentioned"].apply(lambda x: len(x))

    # URLS
    #current_df["urls"] = current_df["content"].apply(lambda x: re.findall(url_reference, x.lower(), flags=re.IGNORECASE))
    #current_df["urls_len"] = current_df["urls_mentioned"].apply(lambda x: len(x))

    # URNS
    #current_df["urns"] = current_df["content"].apply(lambda x: re.findall(urn_reference, x.lower(), flags=re.IGNORECASE))
    #current_df["urns_len"] = current_df["urns_mentioned"].apply(lambda x: len(x))

    # IPV4
    #current_df["ipv4"] = current_df["content"].apply(lambda x: re.findall(ipv4_address, x.lower(), flags=re.IGNORECASE))
    #current_df["ipv4_len"] = current_df["ipv4_mentioned"].apply(lambda x: len(x))

    # IPV6
    #current_df["ipv6"] = current_df["content"].apply(lambda x: re.findall(ipv6_address_or_addrz, x.lower(), flags=re.IGNORECASE))
    #current_df["ipv6_len"] = current_df["ipv6_mentioned"].apply(lambda x: len(x))

    crimeBB_df = pd.concat([crimeBB_df, current_df], ignore_index=True)

# %%
crimeBB_df.shape, crimeBB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51135879 entries, 0 to 51135878
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   post_id             int64
#  1   site_id             int64
#  2   board_id            int64
#  3   thread_id           int64
#  4   user_id             int64
#  5   content             object
#  6   post_data_creation  object
#  7   ipv4_mentioned      object
#  8   ipv4_mentioned_len  int64
#  9   ipv6_mentioned      object
#  10  ipv6_mentioned_len  int64
# dtypes: int64(7), object(4)
# memory usage: 4.2+ GB
# ((51135879, 11), None)

# %%
crimeBB_df
# Out:
#           post_id  site_id  board_id  thread_id  user_id  \
# 0             255        6         2          8       25
# 1             263        6         2          8       20
# 2             251        6         2          8        2
# 3             248        6         2          8       25
# 4             108        6         2          8        1
# ...           ...      ...       ...        ...      ...
# 51135874     9372        5         9       1041     8227
# 51135875     9371        5         9       1041     9424
# 51135876     9370        5         9       1041     8824
# 51135877     9369        5         9       1041    10147
# 51135878     9385        5        25       1042    10229
#
#                                                     content  \
# 0         ***CITING***[https://greysec.net/showthread.ph...
# 1         Great work Insider.\nMany people where waiting...
# 2         ***CITING***[https://greysec.net/showthread.ph...
# 3         Finally GreySec opened!\nCongratulations Insid...
# 4         I'm glad to see that everyone is motivated so ...
# ...                                                     ...
# 51135874  Vouch, this guy is huge, really good power and...
# 51135875  Vouch. have worked & still plan to work for hi...
# 51135876                     Vouch man op asf\n\n\nsaaaaame
# 51135877  Free Hub Status: Enabled (500s 1Gbit/s)\n\n***...
# 51135878  Looking to buy a CF UAM Bypass script that sup...
#
#                      post_data_creation ipv4_mentioned  ipv4_mentioned_len  \
# 0                2015-06-11 12:44:00-03             []                   0
# 1                2015-06-11 14:16:00-03             []                   0
# 2                2015-06-11 12:36:00-03             []                   0
# 3                2015-06-11 11:57:00-03             []                   0
# 4                2015-06-10 13:41:00-03             []                   0
# ...                                 ...            ...                 ...
# 51135874  2018-04-08 23:02:56.514235-03             []                   0
# 51135875  2018-04-08 22:02:56.714347-03             []                   0
# 51135876  2018-04-08 22:02:56.905829-03             []                   0
# 51135877  2018-04-08 22:02:57.195735-03             []                   0
# 51135878  2018-04-09 03:06:49.732599-03             []                   0
#
#          ipv6_mentioned  ipv6_mentioned_len
# 0                    []                   0
# 1                    []                   0
# 2                    []                   0
# 3                    []                   0
# 4                    []                   0
# ...                 ...                 ...
# 51135874             []                   0
# 51135875             []                   0
# 51135876             []                   0
# 51135877             []                   0
# 51135878             []                   0
#
# [51135879 rows x 11 columns]

# %% [markdown]
# ### Word References

# %% [markdown]
# #### Siemens references

# %%
keywords=["siemens", "siemens s7", "simatic s7", "simatic"]

pattern = '|'.join(keywords)

# %%
siemens_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
siemens_df.info(), siemens_df.shape, siemens_df.iloc[0,:]

# %%
siemens_content = ' '.join(siemens_df["content"])

# %%
siemens_dict = get_words_frequency(siemens_content)
len(siemens_dict)

# %%
showWordCloud(siemens_dict, f"Siemens-Wordcloud", max_words=int(len(siemens_dict)))

# %% [markdown]
# #### Port references

# %%
keywords=["port102", "port:102", "bacnet"]

pattern = '|'.join(keywords)

# %%
port102_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
port102_df.info(), port102_df.shape, port102_df.iloc[0,:]

# %%
port102_content = ' '.join(port102_df["content"])

# %%
port102_dict = get_words_frequency(port102_content)
len(port102_dict)

# %%
showWordCloud(port102_dict, "Port:102-Wordcloud", max_words=int(len(port102_dict)))

# %% [markdown]
# #### CVSS references

# %%
keywords=["cvss"]

pattern = '|'.join(keywords)

# %%
cvss_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
cvss_df.info(), cvss_df.shape, cvss_df.iloc[0,:]

# %%
cvss_content = ' '.join(cvss_df["content"])

# %%
cvss_dict = get_words_frequency(cvss_content)
len(cvss_dict)

# %%
showWordCloud(cvss_dict, f"CVSS-Wordcloud", max_words=int(len(cvss_dict)))

# %% [markdown]
# #### EPSS references

# %%
keywords=["epss"]

pattern = '|'.join(keywords)

# %%
epss_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
epss_df.info(), epss_df.shape, epss_df.iloc[0,:]

# %%
epss_content = ' '.join(epss_df["content"])

# %%
epss_dict = get_words_frequency(epss_content)
len(epss_dict)

# %%
showWordCloud(epss_dict, f"EPSS-Wordcloud", max_words=int(len(epss_dict)))

# %% [markdown]
# #### FUD references

# %%
keywords=["fud"]

pattern = '|'.join(keywords)

# %%
fud_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
fud_df.info(), fud_df.shape, fud_df.iloc[0,:]

# %%
fud_content = ' '.join(fud_df["content"])

# %%
fud_dict = get_words_frequency(fud_content)
len(fud_dict)

# %%
showWordCloud(fud_dict, f"FUD-Wordcloud", max_words=int(len(fud_dict)))

# %% [markdown]
# #### SHODAN references

# %%
keywords=["shodan"]

pattern = '|'.join(keywords)

# %%
shodan_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
shodan_df.info(), shodan_df.shape, shodan_df.iloc[0,:]

# %%
shodan_content = ' '.join(shodan_df["content"])

# %%
shodan_dict = get_words_frequency(shodan_content)
len(shodan_dict)

# %%
shodan_dict

# %%
showWordCloud(shodan_dict, "SHODAN-Wordcloud", max_words=int(len(shodan_dict)))

# %% [markdown]
# #### COVID References

# %%
keywords=["covid", "covid19", "covid-19", "sars", "sars-cov-2", "sars-cov"]

pattern = '|'.join(keywords)

# %%
covid_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
covid_df.info(), covid_df.shape, covid_df.iloc[0,:]

# %%
covid_content = ' '.join(covid_df["content"])

# %%
covid_dict = get_words_frequency(covid_content)
len(covid_dict)

# %%
showWordCloud(covid_dict, "COVID-Wordcloud", max_words=int(len(covid_dict)))

# %% [markdown]
# #### CVE references

# %%
keywords=["cve"]

pattern = '|'.join(keywords)

# %%
cve_df = crimeBB_df[crimeBB_df["content"].str.lower().str.contains(pattern)]
cve_df.info(), cve_df.shape, cve_df.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7034 entries, 26 to 51128309
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             7034 non-null   int64
#  1   site_id             7034 non-null   int64
#  2   board_id            7034 non-null   int64
#  3   thread_id           7034 non-null   int64
#  4   user_id             7034 non-null   int64
#  5   content             7034 non-null   object
#  6   post_data_creation  7034 non-null   object
#  7   ipv4_mentioned      7034 non-null   object
#  8   ipv4_mentioned_len  7034 non-null   int64
#  9   ipv6_mentioned      7034 non-null   object
#  10  ipv6_mentioned_len  7034 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 659.4+ KB
# (None,
#  (7034, 11),
#  post_id                                                              21
#  site_id                                                               6
#  board_id                                                             20
#  thread_id                                                            15
#  user_id                                                               1
#  content               Just found this blog filled with security tuto...
#  post_data_creation                               2015-06-09 23:16:00-03
#  ipv4_mentioned                                                       []
#  ipv4_mentioned_len                                                    0
#  ipv6_mentioned                                                       []
#  ipv6_mentioned_len                                                    0
#  Name: 26, dtype: object)

# %%
cve_content = ' '.join(cve_df["content"])

# %%
cve_dict = get_words_frequency(cve_content)
len(cve_dict)

# %%
showWordCloud(covid_dict, "CVE-Wordcloud", max_words=int(len(cve_dict)))

# %% [markdown]
# #### Focus on CVE

# %%
cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve[-]?[0-9]*[-]?[0-9]*)', x.lower(), flags=re.IGNORECASE) )
# Out:
# /tmp/ipykernel_855020/1349211113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve-[0-9]*-[0-9]*)', x.lower(), flags=re.IGNORECASE) )

# %%
cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve-[0-9]*-[0-9]*)', x.lower(), flags=re.IGNORECASE) )
# Out:
# /tmp/ipykernel_855020/1349211113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve-[0-9]*-[0-9]*)', x.lower(), flags=re.IGNORECASE) )

# %%
cve_df["cve_codes"]
# Out:
# 26          [cve-2014-6271, cve-2012-1823, cve-2012-3152, ...
# 3794                                                       []
# 3897                                          [cve-2015-7755]
# 3948                                                       []
# 4375                                          [cve-2014-6300]
#                                   ...
# 51128081                                                   []
# 51128127                                                   []
# 51128134                                                   []
# 51128146                                                   []
# 51128309                                                   []
# Name: cve_codes, Length: 7034, dtype: object

# %%
import itertools
cve_list = list(set(list(itertools.chain(*cve_df["cve_codes"].values.tolist()))))
cve_list, len(cve_list)
# Out:
# ['cve-2014-5446',
#  'cve-2014-0300',
#  'cve-2017-9483',
#  'cve-2008-2758',
#  'cve-2016-0051',
#  'cve-2014-3541',
#  'cve-2014-3165',
#  'cve-2012-5692',
#  'cve-2011-4899',
#  'cve-2014-0499',
#  'cve-2018-8373',
#  'cve-2009-1136',
#  'cve-2005-0244',
#  'cve-2004-2687',
#  'cve-2018-8359',
#  'cve-2000-0413',
#  'cve-2017-8312',
#  'cve-2010-3128',
#  'cve-2010-0806',
#  'cve-2017-6077',
#  'cve-2015-0339',
#  'cve-2017-13087',
#  'cve-2019-12735',
#  'cve-2003-0542',
#  'cve-2012-3577',
#  'cve-2018-1303',
#  'cve-2013-1681',
#  'cve-2015-0097',
#  'cve-2010-3888',
#  'cve-2012-5074',
#  'cve-2017-5638',
#  'cve-2008-1247',
#  'cve-2016-1000030',
#  'cve-2010-2568',
#  'cve-2017-0143',
#  'cve-2014-0983',
#  'cve-2009-2267',
#  'cve-2015-0334',
#  'cve-2013-5327',
#  'cve-2013-3195',
#  'cve-2010-1899',
#  'cve-2013-1313',
#  'cve-2010-2190',
#  'cve-2009-0927',
#  'cve-2013-0230',
#  'cve-2012-5215',
#  'cve-2014-0501',
#  'cve-2010-2772',
#  'cve-1111-11111',
#  'cve-2013-0641',
#  'cve-2017-5459',
#  'cve-2015-1635',
#  'cve-2011-0411',
#  'cve-2013-0632',
#  'cve-2018-8389',
#  'cve-2016-582384',
#  'cve-2009-1862',
#  'cve-2017-14596',
#  'cve-2011-0227',
#  'cve-2019-6111',
#  'cve-2016-0728',
#  'cve-2013-3894',
#  'cve-2014-9239',
#  'cve-2015-0016',
#  'cve-2009-0113',
#  'cve-2007-4453',
#  'cve-2015-0003',
#  'cve-2011-3544',
#  'cve-2017-11429',
#  'cve-2012-5377',
#  'cve-2016-4071',
#  'cve-2011-2140',
#  'cve-2014-0160',
#  'cve-2014-0460',
#  'cve-2016-8870',
#  'cve-2007-1531',
#  'cve-2004-2761',
#  'cve-2015-5600',
#  'cve-2018-8353',
#  'cve-2014-7187',
#  'cve-2013-1763',
#  'cve-2014-3571',
#  'cve-2013-2704',
#  'cve-2018-7538',
#  'cve-2012-2981',
#  'cve-2014-2413',
#  'cve-2015-6812',
#  'cve-2018-1283',
#  'cve-2013-3174',
#  'cve-2007-3847',
#  'cve-2018-2893',
#  'cve-2015-7358',
#  'cve-2017-0147',
#  'cve-2017-3169',
#  'cve-2014-2402',
#  'cve-2013-5988',
#  'cve-2008-4096',
#  'cve-2014-0196',
#  'cve-2010-1423',
#  'cve-2019-12874',
#  'cve-2014-4227',
#  'cve-2010-2883',
#  'cve-2006-4847',
#  'cve-2014-0496',
#  'cve-1999-0502',
#  'cve-2017-7679',
#  'cve-2015-3052',
#  'cve-2014-0451',
#  'cve-2015-0057',
#  'cve-2018-17189',
#  'cve-2004-2111',
#  'cve-2014-3404',
#  'cve-2012-6633',
#  'cve-2012-1182',
#  'cve-2017-8464',
#  'cve-2016-9078',
#  'cve-2013-4124',
#  'cve-2010-1297',
#  'cve-2009-3129',
#  'cve-2015-0240',
#  'cve-2014-0546',
#  'cve-2017-11281',
#  'cve-2006-3677',
#  'cve-2015-3306',
#  'cve-2014-9033',
#  'cve-2010-3867',
#  'cve-2017-5565',
#  'cve-2014-0307',
#  'cve-2010-3944',
#  'cve-2017-3599',
#  'cve-2017-0213',
#  'cve-2014-2483',
#  'cve-2013-6129',
#  'cve-2017-7089',
#  'cve-2006-4704',
#  'cve-2010-1240',
#  'cve-2009-0950',
#  'cve-2017-16943',
#  'cve-2012-2122',
#  'cve-2015-1637',
#  'cve-2014-2838',
#  'cve-2017-11428',
#  'cve-2013-1690',
#  'cve-2013-3522',
#  'cve-2017-1000250',
#  'cve-2018-14634',
#  'cve-2011-0762',
#  'cve-2008-1447',
#  'cve-2007-5000',
#  'cve-2012-2531',
#  'cve-2016-7878',
#  'cve-2015-0002',
#  'cve-2012-2532',
#  'cve-2015-7858',
#  'cve-2014-3566',
#  'cve-2011-4908',
#  'cve-2018-8589',
#  'cve-2012-5378',
#  'cve-2015-0336',
#  'cve-2017-13082',
#  'cve-2015-3826',
#  'cve-2015-5949',
#  'cve-2012-0056',
#  'cve-2009-3560',
#  'cve-2018-8120',
#  'cve-2012-1723',
#  'cve-2017-0261',
#  'cve-2018-0489',
#  'cve-2014-0315',
#  'cve-2010-4258',
#  'cve-2008-4308',
#  'cve-2011-2202',
#  'cve-2015-7547',
#  'cve-2009-2698',
#  'cve-2016-4656',
#  'cve-2013-2010',
#  'cve-2013-209',
#  'cve-2010-3333',
#  'cve-2011-2461',
#  'cve-2013-2729',
#  'cve-2008-2666',
#  'cve-2016-0167',
#  'cve-2016-7876',
#  'cve-2013-0633',
#  'cve-2030-1862',
#  'cve-2015-3828',
#  'cve-2013-2067',
#  'cve-2015-3046',
#  'cve-2016-1247',
#  'cve-2018-18963',
#  'cve-2016-0187',
#  'cve-2010-1000',
#  'cve-2011-0609',
#  'cve-2000-0011',
#  'cve-2014-2410',
#  'cve-2013-2574',
#  'cve-2012-3414',
#  'cve-2014-1761',
#  'cve-2017-14315',
#  'cve-2017-',
#  'cve-2019-6340',
#  'cve-2012-1875',
#  'cve-2018-1301',
#  'cve-2016-7867',
#  'cve-2014-5119',
#  'cve-2013-3256',
#  'cve-2005-1794',
#  'cve-2018-11512',
#  'cve-2018-5002',
#  'cve-2013-3346',
#  'cve-2014-2420',
#  'cve-2010-1623',
#  'cve-2016-3393',
#  'cve-2010-3147',
#  'cve-2019-13272',
#  'cve-2009-3269',
#  'cve-2016-0701',
#  'cve-2008-3660',
#  'cve-2014-0498',
#  'cve-2014-0224',
#  'cve-2011-1255',
#  'cve-2009-3697',
#  'cve-2010-3081',
#  'cve-2015-6152',
#  'cve-2016-2183',
#  'cve-2014-0446',
#  'cve-2012-0151',
#  'cve-2007-3304',
#  'cve-2017-6186',
#  'cve-2012-0782',
#  'cve-2010-0886',
#  'cve-2018-8414',
#  'cve-2018-1038',
#  'cve-2015-3827',
#  'cve-2018-7602',
#  'cve-2015-031',
#  'cve-2012-4366',
#  'cve-2013-2251',
#  'cve-2015-5119',
#  'cve-2010-3904',
#  'cve-2017-8310',
#  'cve-2013-2097',
#  'cve-2015-0359',
#  'cve-2005-1983',
#  'cve-2012-0789',
#  'cve-2013-3899',
#  'cve-2018-1000049',
#  'cve-2015-5123',
#  'cve-2008-3659',
#  'cve-2009-4018',
#  'cve-2014-2401',
#  'cve-2013-3684',
#  'cve-2017-6417',
#  'cve-2012-1823',
#  'cve-2012-1856',
#  'cve-2015-2545',
#  'cve-2018-15919',
#  'cve-2015-4025',
#  'cve-2011-3192',
#  'cve-2014-2022',
#  'cve-2017-5566',
#  'cve-2010-3971',
#  'cve-2015-4002',
#  'cve-2017-0226',
#  'cve-2016-7262',
#  'cve-2016-7869',
#  'cve-2002-0082',
#  'cve-2010-1860',
#  'cve-2013-2463',
#  'cve-2007-4653',
#  'cve-2016-6366',
#  'cve-2017-14495',
#  'cve-2016-6174',
#  'cve-2014-4148',
#  'cve-2017-8291',
#  'cve-2008-0128',
#  'cve-2015-432143',
#  'cve-2013-1294',
#  'cve-2008-4844',
#  'cve-2015-0231',
#  'cve-2013-27',
#  'cve-2013-3866',
#  'cve-2011-4885',
#  'cve-2015-1770',
#  'cve-2010-1598',
#  'cve-2017-11427',
#  'cve-2016-7890',
#  'cve-2010-0094',
#  'cve-2011-1485',
#  'cve-2016-7875',
#  'cve-2018-0802',
#  'cve-2011-0414',
#  'cve-2017-2835',
#  'cve-2007-0882',
#  'cve-2014-0458',
#  'cve-2014-0768',
#  'cve-2009-1534',
#  'cve-2012-',
#  'cve-2012-5380',
#  'cve-2016-6662',
#  'cve-2019-10692',
#  'cve-2008-5624',
#  'cve-2016-0792',
#  'cve-2016-0034',
#  'cve-2013-3196',
#  'cve-2008-2939',
#  'cve-2013-3576',
#  'cve-2011-3607',
#  'cve-2014-0453',
#  'cve-2014-1972',
#  'cve-2015-1745',
#  'cve-2017-13077',
#  'cve-2017-0262',
#  'cve-2009-0288',
#  'cve-2013-',
#  'cve-2016-0016',
#  'cve-2018-6789',
#  'cve-2014-8350',
#  'cve-2015-3043',
#  'cve-2017-7494',
#  'cve-2015-2502',
#  'cve-2014-9038',
#  'cve-2006-5202',
#  'cve-2012-2983',
#  'cve-2014-3694',
#  'cve-2014-7186',
#  'cve-2015-3673',
#  'cve-2009-3095',
#  'cve-2014-2398',
#  'cve-2018-11763',
#  'cve-2015-1205',
#  'cve-2014-0323',
#  'cve-2014-0455',
#  'cve-2012-0003',
#  'cve-2018-17182',
#  'cve-2014-1849',
#  'cve-2014-3911',
#  'cve-2017-14494',
#  'cve-2014-2421',
#  'cve-2011-0226',
#  'cve-2013-3181',
#  'cve-2016-3427',
#  'cve-2015-0701',
#  'cve-2015-3036',
#  'cve-2016-1001',
#  'cve-2005-1781',
#  'cve-2016-3351',
#  'cve-2017-15220',
#  'cve-2011-3368',
#  'cve-2014-0985',
#  'cve-2013-3129',
#  'cve-2012-0507',
#  'cve-2014-4971',
#  'cve-2010-3848',
#  'cve-2014-0456',
#  'cve-2003-0127',
#  'cve-2013-3200',
#  'cve-2014-496',
#  'cve-2005-3683',
#  'cve-2013-2471',
#  'cve-2007-3464',
#  'cve-2011-5046',
#  'cve-2016-1908',
#  'cve-2013-3336',
#  'cve-2007-3462',
#  'cve-2009-3720',
#  'cve-2013-3887',
#  'cve-2013-3528',
#  'cve-2010-2744',
#  'cve-2015-3824',
#  'cve-2012-6080',
#  'cve-2017-1000251',
#  'cve-2013-6227',
#  'cve-2012-0814',
#  'cve-2010-3065',
#  'cve-2008-5557',
#  'cve-2015-3050',
#  'cve-2013-0002',
#  'cve-2010-0231',
#  'cve-2013-3869',
#  'cve-2013-3172',
#  'cve-2014-1876',
#  'cve-2019-0808',
#  'cve-2015-1766',
#  'cve-2017-0783',
#  'cve-2012-0168',
#  'cve-2013-3878',
#  'cve-2018-1312',
#  'cve-2018-8355',
#  'cve-2009-3843',
#  'cve-2013-4322',
#  'cve-2007-1863',
#  'cve-2013-0011',
#  'cve-2011-4415',
#  'cve-2014-2428',
#  'cve-2015-1641',
#  'cve-1999-0103',
#  'cve-2012-5868',
#  'cve-2015-3200',
#  'cve-2010-3437',
#  'cve-2018-4878',
#  'cve-2013-2465',
#  'cve-2015-6834',
#  'cve-2014-0319',
#  'cve-2017-11282',
#  'cve-2013-6226',
#  'cve-2018-8372',
#  'cve-2010-4478',
#  'cve-2018-0986',
#  'cve-2014-6321',
#  'cve-2011-0920',
#  'cve-2018-1234',
#  'cve-2015-3057',
#  'cve-2014-3669',
#  'cve-2012-3451',
#  'cve-2006-7243',
#  'cve-2011-2768',
#  'cve-2010-1864',
#  'cve-2019-11091',
#  'cve-2014-0504',
#  'cve-2006-5052',
#  'cve-2016-5773',
#  'cve-2014-3153',
#  'cve-2010-3653',
#  'cve-2016-3169',
#  'cve-2013-2094',
#  'cve-2018-0029',
#  'cve-2017-14496',
#  'cve-2018-10933',
#  'cve-2013-3853',
#  'cve-2013-3173',
#  'cve-2015-7755',
#  'cve-2015-5663',
#  'cve-2014-0322',
#  'cve-2015-2360',
#  'cve-2008-3184',
#  'cve-2017-7200',
#  'cve-2016-6663',
#  'cve-2015-0311',
#  'cve-2012-0217',
#  'cve-2009-2265',
#  'cve-2005-0560',
#  'cve-2010-5297',
#  'cve-2014-2414',
#  'cve-2017-13704',
#  'cve-2014-0173',
#  'cve-2008-5250',
#  'cve-2014-0301',
#  'cve-2017-15303',
#  'cve-2017-8570',
#  'cve-2009-0355',
#  'cve-2018-8385',
#  'cve-2015-1283',
#  'cve-2015-1862',
#  'cve-2018-16858',
#  'cve-2014-0038',
#  'cve-2018-7600',
#  'cve-2015-4600',
#  'cve-2010-3563',
#  'cve-2004-0789',
#  'cve-2015-3864',
#  'cve-2017-8311',
#  'cve-2008-5499',
#  'cve-2014-4455',
#  'cve-2013-3081',
#  'cve-2011-1220',
#  'cve-2017-3823',
#  'cve-2007-1862',
#  'cve-2014-0452',
#  'cve-2017-13088',
#  'cve-2014-0454',
#  'cve-2017-9490',
#  'cve-2010-2963',
#  'cve-2015-8562',
#  'cve-2013-1347',
#  'cve-2009-1161',
#  'cve-2016-7892',
#  'cve-2017-7529',
#  'cve-2019-0859',
#  'cve-2016-0189',
#  'cve-2018-17199',
#  'cve-2009-1151',
#  'cve-2013-6837',
#  'cve-2015-0312',
#  'cve-2015-0802',
#  'cve-2015-6636',
#  'cve-2019-0217',
#  'cve-2015-1487',
#  'cve-2014-6300',
#  'cve-2014-8686',
#  'cve-2017-0146',
#  'cve-2017-8628',
#  'cve-2015-6835',
#  'cve-1999-0024',
#  'cve-2018-8371',
#  'cve-2017-11937',
#  'cve-2016-4625',
#  'cve-2010-4221',
#  'cve-2013-0421',
#  'cve-2012-0779',
#  'cve-2017-0144',
#  'cve-2013-3136',
#  'cve-2013-1342',
#  'cve-2013-7331',
#  'cve-2018-10561',
#  'cve-2016-0998',
#  'cve-2014-0332',
#  'cve-2011-3189',
#  'cve-2017-5689',
#  'cve-2013-5576',
#  'cve-2018-6376',
#  'cve-2007-4781',
#  'cve-2014-2409',
#  'cve-2014-8724',
#  'cve-2019-0797',
#  'cve-2018-12130',
#  'cve-2014-6071',
#  'cve-2000-0155',
#  'cve-2015-4599',
#  'cve-2012-0002',
#  'cve-2012-1535',
#  'cve-2014-9912',
#  'cve-2012-0915',
#  'cve-2006-3227',
#  'cve-2014-1691',
#  'cve-2017-12170',
#  'cve-2013-2173',
#  'cve-2015-0337',
#  'cve-2007-3314',
#  'cve-2005-0690',
#  'cve-2015-4495',
#  'cve-2011-2769',
#  'cve-2019-0708',
#  'cve-2014-7152',
#  'cve-2015-4601',
#  'cve-2018-20250',
#  'cve-2019-3915',
#  'cve-2017-6530',
#  'cve-2010-0232',
#  'cve-2012-4792',
#  'cve-2017-8313',
#  'cve-2010-2191',
#  'cve-2007-1036',
#  'cve-2005-4659',
#  'cve-2008-2371',
#  'cve-2017-5567',
#  'cve-2014-1716',
#  'cve-2017-9805',
#  'cve-2012-0053',
#  'cve-2011-0257',
#  'cve-2011-0923',
#  'cve-2010-1870',
#  'cve-2017-0199',
#  'cve-2017-17094',
#  'cve-2012-2687',
#  'cve-2014-2397',
#  'cve-2014-0429',
#  'cve-2015-3090',
#  'cve-2006-0003',
#  'cve-2013-3897',
#  'cve-2011-5129',
#  'cve-2006-5051',
#  'cve-2013-6954',
#  'cve-2017-3216',
#  'cve-2017-13215',
#  'cve-2016-1960',
#  'cve-2017-3167',
#  'cve-2013-5065',
#  'cve-2016-4117',
#  'cve-20120-0507',
#  'cve-2013-1345',
#  'cve-1999-0269',
#  'cve-2012-6348',
#  'cve-2014-0050',
#  'cve-2015-0235',
#  'cve-2002-1507',
#  'cve-2014-9463',
#  'cve-2013-3865',
#  'cve-2014-1710',
#  'cve-2008-5353',
#  'cve-2016-10735',
#  'cve-2014-3738',
#  'cve-2013-1311',
#  'cve-2010-0404',
#  'cve-2018-18094',
#  'cve-2012-0754',
#  'cve-2013-0337',
#  'cve-2018-14773',
#  'cve-2010-0842',
#  'cve-2008-4609',
#  'cve-2016-6483',
#  'cve-2013-3128',
#  'cve-2013-1334',
#  'cve-2013-1331',
#  'cve-2016-10112',
#  'cve-2015-1493',
#  'cve-2010-1885',
#  'cve-1999-0738',
#  'cve-2016-4655',
#  'cve-2013-3167',
#  'cve-2017-14492',
#  'cve-2010-2075',
#  'cve-2012-5959',
#  'cve-2013-5211',
#  'cve-2010-2097',
#  'cve-2019-0196',
#  'cve-2006-0295',
#  'cve-2013-0431',
#  'cve-2011-1764',
#  'cve-2019-1151',
#  'cve-2010-2531',
#  'cve-2017-3881',
#  'cve-2013-1341',
#  'cve-2000-0709',
#  'cve-2013-2551',
#  'cve-2012-0261',
#  'cve-2014-0503',
#  'cve-2017-7269',
#  'cve-2015-0310',
#  'cve-2015-6174',
#  'cve-2008-2829',
#  'cve-2015-1100',
#  'cve-2013-4286',
#  'cve-2017-13086',
#  'cve-2015-2445',
#  'cve-2015-4603',
#  'cve-2013-01',
#  'cve-2016-1646',
#  'cve-2015-1744',
#  'cve-2017-9948',
#  'cve-2005-3536',
#  'cve-2016-6195',
#  'cve-2017-0290',
#  'cve-2010-3129',
#  'cve-2016-7870',
#  'cve-2008-0908',
#  'cve-2015-1650',
#  'cve-2013-0235',
#  'cve-2015-7359',
#  'cve-2010-1807',
#  'cve-2014-5240',
#  'cve-2016-5771',
#  'cve-2014-0569',
#  'cve-2019-1653',
#  'cve-2014-0266',
#  'cve-2016-7274',
#  'cve-2013-3918',
#  'cve-2019-10149',
#  'cve-2013-3876',
#  'cve-2013-3893',
#  'cve-2015-0090',
#  'cve-2013-0056',
#  'cve-2015-1740',
#  'cve-2017-6506',
#  'cve-2015-3070',
#  'cve-2008-1930',
#  'cve-2015-0816',
#  'cve-2017-0148',
#  'cve-2011-3402',
#  'cve-2002-2353',
#  'cve-2009-2764',
#  'cve-2006-4379',
#  'cve-2017-15715',
#  'cve-2017-2362',
#  'cve-1999-0183',
#  'cve-2011-1002',
#  'cve-2014-6324',
#  'cve-2012-5383',
#  'cve-2013-5330',
#  'cve-2013-0074',
#  'cve-2006-2172',
#  'cve-2017-11151',
#  'cve-2018-4160',
#  'cve-2013-3661',
#  'cve-2017-0782',
#  'cve-2002-0656',
#  'cve-2016-7200',
#  'cve-2019-9848',
#  'cve-2006-2369',
#  'cve-2010-3227',
#  'cve-2013-3863',
#  'cve-2013-3940',
#  'cve-2015-6764',
#  'cve-2011-2330',
#  'cve-2017-8759',
#  'cve-2014-8449',
#  'cve-2013-1344',
#  'cve-2008-2992',
#  'cve-2009-4250',
#  'cve-2015-5352',
#  'cve-2009-1869',
#  'cve-2014-1815',
#  'cve-2010-3654',
#  'cve-2013-3854',
#  'cve-2013-0239',
#  'cve-2012-2619',
#  'cve-2017-0166',
#  'cve-2012-6079',
#  'cve-2008-5625',
#  'cve-2010-0818',
#  'cve-2012-4871',
#  'cve-2010-2861',
#  'cve-2008-7252',
#  'cve-2011-4969',
#  'cve-2014-2265',
#  'cve-2015-7808',
#  'cve-2017-7479',
#  'cve-2014-3704',
#  'cve-2016-2554',
#  'cve-2016-1019',
#  'cve-2016-0012',
#  'cve-2014-0346',
#  'cve-2018-11440',
#  'cve-2017-12166',
#  'cve-2016-0777',
#  'cve-2013-33465065',
#  'cve-2008-0923',
#  'cve-2010-3552',
#  'cve-2014-6041',
#  'cve-2014-4114',
#  'cve-2014-6343',
#  'cve-2009-4324',
#  'cve-2006-4893',
#  'cve-2017-6366',
#  'cve-2013-6629',
#  'cve-2014-0515',
#  'cve-2016-9416',
#  'cve-2013-0229',
#  'cve-2014-1510',
#  'cve-2016-0778',
#  'cve-2001-1013',
#  'cve-2012-6708',
#  'cve-2010-4276',
#  'cve-2010-1511',
#  'cve-2018-8453',
#  'cve-2014-1266',
#  'cve-2014-9031',
#  'cve-2010-2100',
#  'cve-2010-2225',
#  'cve-2019-1181',
#  'cve-2011-609',
#  'cve-2013-2460',
#  'cve-1999-0531',
#  'cve-2014-032',
#  'cve-2007-6388',
#  'cve-2018-6242',
#  'cve-2014-7188',
#  'cve-2012-3152',
#  'cve-2008-0166',
#  'cve-2014-0448',
#  'cve-2010-4452',
#  'cve-2008-3658',
#  'cve-2014-0463',
#  'cve-2007-1044',
#  'cve-2012-6078',
#  'cve-2009-1244',
#  'cve-2015-7857',
#  'cve-2005-3252',
#  'cve-2012-5088',
#  'cve-2013-0640',
#  'cve-2013-4022',
#  'cve-2012-6636',
#  'cve-2019-1432',
#  'cve-2011-1751',
#  'cve-2016-5051',
#  'cve-2013-0634',
#  'cve-2018-10562',
#  'cve-2017-0099',
#  'cve-2014-2053',
#  'cve-2017-14491',
#  'cve-2015-2369',
#  'cve-2014-0459',
#  'cve-2017-15710',
#  'cve-2018-15982',
#  'cve-2013-1732',
#  'cve-2010-1862',
#  'cve-2017-16995',
#  'cve-2011-2462',
#  'cve-2015-3105',
#  'cve-2013-4339',
#  'cve-2008-1818',
#  'cve-2012-6495',
#  'cve-2016-7879',
#  'cve-2013-4465',
#  'cve-2018-8390',
#  'cve-2018-12126',
#  'cve-2013-4588',
#  'cve-2014-5203',
#  'cve-2015-1318',
#  'cve-2014-0464',
#  'cve-2015-3056',
#  'cve-2013-1493',
#  'cve-2017-9841',
#  'cve-2011-4862',
#  'cve-2007-5755',
#  'cve-2016-9838',
#  'cve-2014-2412',
#  'cve-2016-0710',
#  'cve-2015-',
#  'cve-2013-3660',
#  'cve-2017-12617',
#  'cve-2014-0497',
#  'cve-2010-0403',
#  'cve-2007-2447',
#  'cve-2014-9034',
#  'cve-2008-0005',
#  'cve-2017-13080',
#  'cve-2016-0099',
#  'cve-2014-6721',
#  'cve-2010-4345',
#  'cve-2014-0502',
#  'cve-2012-4969',
#  'cve-2015-0315',
#  'cve-2010-4398',
#  'cve-2013-6117',
#  'cve-2011-1519',
#  'cve-2016-8735',
#  'cve-2014-3188',
#  'cve-2014-8243',
#  'cve-2018-1333',
#  'cve-2011-0611',
#  'cve-2013-3238',
#  'cve-2017-6344',
#  'cve-2013-5058',
#  'cve-2017-5375',
#  'cve-2016-2819',
#  'cve-2016-6210',
#  'cve-2015-0333',
#  'cve-2013-1670',
#  'cve-2009-0993',
#  'cve-2014-0461',
#  'cve-2014-3515',
#  'cve-2017-14493',
#  'cve-2014-5204',
#  'cve-2017-2834',
#  'cve-2016-3313',
#  'cve-2019-6110',
#  'cve-2006-3747',
#  'cve-2017-14723',
#  'cve-2014-7911',
#  'cve-2016-4484',
#  'cve-2017-13084',
#  'cve-2010-2884',
#  'cve-2010-0746',
#  'cve-2012-4681',
#  'cve-2016-9079',
#  'cve-2018-9422',
#  'cve-2013-1300',
#  'cve-2011-3615',
#  'cve-2015-7645',
#  'cve-2015-3073',
#  'cve-2014-6271',
#  'cve-2015-4602',
#  'cve-99-9',
#  'cve-2012-0158',
#  'cve-2011-3389',
#  'cve-2013-3175',
#  'cve-2011-4361',
#  'cve-2011-0202',
#  'cve-2015-0335',
#  'cve-2011-252',
#  'cve-2018-8233',
#  'cve-2001-0264',
#  'cve-2016-7880',
#  'cve-2018-8611',
#  'cve-2016-3238',
#  'cve-2009-3103',
#  'cve-2011-4898',
#  'cve-2010-1850',
#  'cve-2009-0806',
#  'cve-2017-0785',
#  'cve-2008-5249',
#  'cve-2005-3419',
#  'cve-2011-0096',
#  'cve-2012-5382',
#  'cve-2013-3197',
#  'cve-2015-2454',
#  'cve-2010-3301',
#  'cve-2015-5122',
#  'cve-2014-2423',
#  'cve-2014-4461',
#  'cve-2013-7236',
#  'cve-2012-5958',
#  'cve-2016-7881',
#  'cve-2014-4451',
#  'cve-2015-0313',
#  'cve-2017-0781',
#  'cve-2008-6506',
#  'cve-2019-3914',
#  'cve-2013-0422',
#  'cve-2015-5589',
#  'cve-2014-0449',
#  'cve-2014-6277',
#  'cve-2013-2566',
#  'cve-2015-3829',
#  'cve-2015-1427',
#  'cve-2015-1539',
#  'cve-2018-15473',
#  'cve-2009-3547',
#  'cve-2008-2665',
#  'cve-2010-0249',
#  'cve-2009-0388',
#  'cve-2015-3076',
#  'cve-2016-7865',
#  'cve-2010-0397',
#  'cve-2012-0394',
#  'cve-2009-3555',
#  'cve-2014-0556',
#  'cve-2009-2693',
#  'cve-2014-0500',
#  'cve-2016-4657',
#  'cve-2017-13078',
#  'cve-2017-15906',
#  'cve-2015-2717',
#  'cve-2001-0263',
#  'cve-2010-2752',
#  'cve-2005-4560',
#  'cve-2016-10074',
#  'cve-2010-2101',
#  'cve-2014-0317',
#  'cve-2015-1735',
#  'cve-2017-13079',
#  'cve-2007-2815',
#  'cve-2008-2100',
#  'cve-2013-4590',
#  'cve-2015-2590',
#  'cve-2010-2730',
#  'cve-2016-5195',
#  'cve-2010-1447',
#  'cve-2010-0840',
#  'cve-2002-0419',
#  'cve-2019-1182',
#  'cve-2009-0271',
#  'cve-2019-11043',
#  'cve-2017-7526',
#  'cve-2018-1302',
#  'cve-2019-0163',
#  'cve-2015-3456',
#  'cve-2018-1000115',
#  'cve-2014-4113',
#  'cve-2014-8439',
#  'cve-2014-9161',
#  'cve-2014-6691',
#  'cve-2015-3049',
#  'cve-2013-1343',
#  'cve-2013-3198',
#  'cve-2006-0960',
#  'cve-2012-1889',
#  'cve-2009-0057',
#  'cve-2017-0176',
#  'cve-2016-3115',
#  'cve-2015-2419',
#  'cve-2010-4701',
#  'cve-2011-0559',
#  'cve-2019-0768',
#  'cve-2000-0710',
#  'cve-2019-101',
#  'cve-2014-3500',
#  'cve-2011-1575',
#  'cve-2019-0541',
#  'cve-2017-11882',
#  'cve-2017-8597',
#  'cve-2013-0322',
#  'cve-2013-1710',
#  'cve-2007-4887',
#  'cve-2015-3051',
#  'cve-2011-2110',
#  'cve-2013-3879',
#  'cve-2013-0346',
#  'cve-2016-7874',
#  'cve-2013-1340',
#  'cve-2017-13081',
#  'cve-2014-0432',
#  'cve-2015-0341',
#  'cve-2016-7241',
#  'cve-2015-3113',
#  'cve-2012-0209',
#  'cve-2016-7877',
#  'cve-2010-3849',
#  'cve-2007-2446',
#  'cve-2016-6515',
#  'cve-2010-0822',
#  'cve-2013-5056',
#  'cve-2012-5615',
#  'cve-2014-6332',
#  'cve-2014-2422',
#  'cve-2007-6421',
#  'cve-2016-10033',
#  'cve-2014-6278',
#  'cve-2014-5205',
#  'cve-2016-3714',
#  'cve-2008-3681',
#  'cve-2014-4348',
#  'cve-2008-4250',
#  'cve-2014-4457',
#  'cve-2013-3906',
#  'cve-2016-10009',
#  'cve-2009-0796',
#  'cve-2019-5786',
#  'cve-2018-0880',
#  ...]
