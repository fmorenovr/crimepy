# %%
import sys, os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from crimebb import *

# %%
#sudo setfacl -m u:postgres:rwx /media/fmorenovr

# %%
DATA_PATH="../data/"
SQL_PATH = f"{DATA_PATH}sql/"
#SQL_PATH = f"/home/fmorenovr/Downloads/data/"

# %% [markdown]
# ### Database connection

# %%
config = openFile(f'{DATA_PATH}/db_config.json')
config_file = config['postgres_connection']
config_file
# Out:
# {'host': 'localhost',
#  'username': 'postgres',
#  'password': '123456',
#  'port': 9200}

# %% [markdown]
# ### Listing sql files and paths

# %%
list_dbs, path_dbs, dict_dbs = get_db_names(f"{SQL_PATH}/*.sql")

print("DB Name\n", list_dbs,"\n")
print("DB Path\n", path_dbs,"\n")
print("DBs Dict\n", dict_dbs,"\n")
# Out:
# DB Name
#  ['antichat-2021-01-10', 'deutschland-im-deep-web-2021-01-10', 'dread-2021-01-10', 'envoy-forum-2021-01-10', 'garage4hackers-2021-01-10', 'raidforums-2021-01-10', 'runion-2021-01-10', 'safe-sky-hacks-2021-01-10', 'the-hub-2021-01-10', 'torum-2021-01-10']
#
# DB Path
#  ['/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-antichat-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-deutschland-im-deep-web-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-dread-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-envoy-forum-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-garage4hackers-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-raidforums-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-runion-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-safe-sky-hacks-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-the-hub-2021-01-10.sql', '/media/fmorenovr/87ae90e0-7049-439e-854e-b9268b9619f3/github/ComputerScience_UFRJ/MAB779-Estudos_Dirigidos_ao_MSc/notebooks/../data/sql/crimebb-torum-2021-01-10.sql']
#
# DBs Dict
#  {'antichat-2021-01-10': '../data/sql/crimebb-antichat-2021-01-10.sql', 'deutschland-im-deep-web-2021-01-10': '../data/sql/crimebb-deutschland-im-deep-web-2021-01-10.sql', 'dread-2021-01-10': '../data/sql/crimebb-dread-2021-01-10.sql', 'envoy-forum-2021-01-10': '../data/sql/crimebb-envoy-forum-2021-01-10.sql', 'garage4hackers-2021-01-10': '../data/sql/crimebb-garage4hackers-2021-01-10.sql', 'raidforums-2021-01-10': '../data/sql/crimebb-raidforums-2021-01-10.sql', 'runion-2021-01-10': '../data/sql/crimebb-runion-2021-01-10.sql', 'safe-sky-hacks-2021-01-10': '../data/sql/crimebb-safe-sky-hacks-2021-01-10.sql', 'the-hub-2021-01-10': '../data/sql/crimebb-the-hub-2021-01-10.sql', 'torum-2021-01-10': '../data/sql/crimebb-torum-2021-01-10.sql'}

# %% [markdown]
# ### List of all current databases

# %%
list_current_dbs = listDBs(config_file)
list_current_dbs
# Out:
# Conn closed 1
# [('postgres',),
#  ('template1',),
#  ('template0',),
#  ('antichat-2021-01-10',),
#  ('deutschland-im-deep-web-2021-01-10',),
#  ('dread-2021-01-10',),
#  ('envoy-forum-2021-01-10',),
#  ('garage4hackers-2021-01-10',),
#  ('raidforums-2021-01-10',),
#  ('runion-2021-01-10',),
#  ('safe-sky-hacks-2021-01-10',),
#  ('the-hub-2021-01-10',),
#  ('torum-2021-01-10',)]

# %% [markdown]
# ### removing databases

# %%
total_list = list(set(list_dbs).union(set([a for (a,) in list_current_dbs if a not in ['postgres', 'template1','template0']])))
total_list
# Out:
# ['deutschland-im-deep-web-2021-01-10',
#  'dread-2021-01-10',
#  'antichat-2021-01-10',
#  'raidforums-2021-01-10',
#  'safe-sky-hacks-2021-01-10',
#  'garage4hackers-2021-01-10',
#  'envoy-forum-2021-01-10',
#  'torum-2021-01-10',
#  'the-hub-2021-01-10',
#  'runion-2021-01-10']

# %%
deleteDBs(config_file, list_dbs, list_current_dbs)
# Out:
# Conn closed 1

# %%
list_current_dbs = listDBs(config_file)
list_current_dbs
# Out:
# Conn closed 1
# [('postgres',), ('template1',), ('template0',)]

# %% [markdown]
# ### Creating databases

# %%
createDBs(config_file, list_dbs, list_current_dbs)
# Out:
# Conn closed 1

# %%
list_current_dbs = listDBs(config_file)
list_current_dbs
# Out:
# Conn closed 1
# [('postgres',),
#  ('template1',),
#  ('template0',),
#  ('antichat-2021-01-10',),
#  ('deutschland-im-deep-web-2021-01-10',),
#  ('dread-2021-01-10',),
#  ('envoy-forum-2021-01-10',),
#  ('garage4hackers-2021-01-10',),
#  ('raidforums-2021-01-10',),
#  ('runion-2021-01-10',),
#  ('safe-sky-hacks-2021-01-10',),
#  ('the-hub-2021-01-10',),
#  ('torum-2021-01-10',)]

# %% [markdown]
# ### Excetuting and creating all tables for each db

# %%
for db_name in list_dbs:
    cmd_db_restore(db_name, dict_dbs[db_name], config_file["password"])
# Out:
# Backuping ... antichat-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 64
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 79887
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Backuping ... deutschland-im-deep-web-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 43
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 2516
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 20185
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 4075
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# COPY 2449404
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 243176
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... dread-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# Senha:
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 446
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 52406
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# COPY 294596
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 75122
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... envoy-forum-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 93
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 364
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 2163
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 454
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... garage4hackers-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 35
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 881
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 7697
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 2096
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... raidforums-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 75
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 46111
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# COPY 214856
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 34798
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 3973
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... runion-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 19
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 17343
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# COPY 240632
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 16867
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... safe-sky-hacks-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 50
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 7471
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 27018
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 12963
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... the-hub-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 62
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 8340
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# COPY 88753
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 11286
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
# Backuping ... torum-2021-01-10
# --
# -- PostgreSQL database dump
# --
# -- Dumped from database version 11.7
# -- Dumped by pg_dump version 11.9
# SET statement_timeout = 0;
# SET
# SET lock_timeout = 0;
# SET
# SET idle_in_transaction_session_timeout = 0;
# SET
# SET client_encoding = 'UTF8';
# SET
# SET standard_conforming_strings = on;
# SET
# SELECT pg_catalog.set_config('search_path', '', false);
#  set_config
# ------------
#
# (1 row)
#
# SET check_function_bodies = false;
# SET
# SET xmloption = content;
# SET
# SET client_min_messages = warning;
# SET
# SET row_security = off;
# SET
# SET default_tablespace = '';
# SET
# SET default_with_oids = false;
# SET
# --
# -- Name: boards; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.boards (
#     id integer,
#     site_id integer,
#     name text,
#     url text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: contracts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.contracts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     type text,
#     maker text,
#     maker_id integer,
#     accepter text,
#     accepter_id integer,
#     started_date timestamp with time zone,
#     completed_date timestamp with time zone,
#     expire_date text,
#     status text,
#     visibility text,
#     maker_obligation text,
#     accepter_obligation text,
#     maker_payment_info text,
#     accepter_payment_info text,
#     term text,
#     is_maker_complete boolean,
#     is_accepter_complele boolean,
#     maker_rating text,
#     accepter_rating text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone,
#     html_source text
# );
# CREATE TABLE
# --
# -- Name: members; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.members (
#     id integer,
#     username text,
#     site_id integer,
#     profile_url text,
#     homepage_url text,
#     avatar_url text,
#     registration_date timestamp with time zone,
#     age integer,
#     signature text,
#     location text,
#     location_time timestamp with time zone,
#     time_spent numeric(20,10),
#     last_visit timestamp with time zone,
#     total_posts integer,
#     first_post_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     reputation integer,
#     prestige integer,
#     is_parsed boolean,
#     other_info text,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: posts; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.posts (
#     id integer,
#     site_id integer,
#     board_id integer,
#     thread_id integer,
#     creator text,
#     creator_id integer,
#     creator_n_posts integer,
#     creator_reputation integer,
#     content text,
#     quoted_post_ids text[],
#     is_a_reply boolean,
#     created_on timestamp with time zone,
#     updated_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: threads; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.threads (
#     id integer,
#     site_id integer,
#     board_id integer,
#     creator text,
#     creator_id integer,
#     label text,
#     name text,
#     url text,
#     created_on timestamp with time zone,
#     last_post_on timestamp with time zone,
#     is_forward_direction boolean,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Name: votes; Type: TABLE; Schema: public; Owner: -
# --
# CREATE TABLE public.votes (
#     id integer,
#     site_id integer,
#     donor_id integer,
#     receiver_id integer,
#     quantity integer,
#     reason text,
#     created_on timestamp with time zone,
#     db_created_on timestamp with time zone,
#     db_updated_on timestamp with time zone
# );
# CREATE TABLE
# --
# -- Data for Name: boards; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.boards (id, site_id, name, url, db_created_on, db_updated_on) FROM stdin;
# COPY 11
# --
# -- Data for Name: contracts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.contracts (id, site_id, board_id, type, maker, maker_id, accepter, accepter_id, started_date, completed_date, expire_date, status, visibility, maker_obligation, accepter_obligation, maker_payment_info, accepter_payment_info, term, is_maker_complete, is_accepter_complele, maker_rating, accepter_rating, db_created_on, db_updated_on, html_source) FROM stdin;
# COPY 0
# --
# -- Data for Name: members; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.members (id, username, site_id, profile_url, homepage_url, avatar_url, registration_date, age, signature, location, location_time, time_spent, last_visit, total_posts, first_post_on, last_post_on, reputation, prestige, is_parsed, other_info, db_created_on, db_updated_on) FROM stdin;
# COPY 3835
# --
# -- Data for Name: posts; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.posts (id, site_id, board_id, thread_id, creator, creator_id, creator_n_posts, creator_reputation, content, quoted_post_ids, is_a_reply, created_on, updated_on, db_created_on, db_updated_on) FROM stdin;
# Senha:
# COPY 28485
# --
# -- Data for Name: threads; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.threads (id, site_id, board_id, creator, creator_id, label, name, url, created_on, last_post_on, is_forward_direction, db_created_on, db_updated_on) FROM stdin;
# COPY 4346
# --
# -- Data for Name: votes; Type: TABLE DATA; Schema: public; Owner: -
# --
# COPY public.votes (id, site_id, donor_id, receiver_id, quantity, reason, created_on, db_created_on, db_updated_on) FROM stdin;
# COPY 0
# --
# -- PostgreSQL database dump complete
# --
