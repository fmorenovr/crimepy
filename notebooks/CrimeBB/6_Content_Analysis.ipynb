# %%
import pandas as pd
import sys, os

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from crimebb import *

# %%
YEAR="2021"

# %%
DATA_PATH="../../data/"
CSV_PROCESSED = f"{DATA_PATH}csv/{YEAR}/processed/"

# %% [markdown]
# ### Loading data

# %%
posts_threads_df = pd.read_csv(f"{CSV_PROCESSED}post_thread_board.csv", sep="\t", low_memory=False)
posts_threads_df.shape, posts_threads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3373789 entries, 0 to 3373788
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   post_id             int64
#  1   site_id             int64
#  2   board_id            int64
#  3   thread_id           int64
#  4   user_id             int64
#  5   site_name           object
#  6   board_title         object
#  7   thread_title        object
#  8   username            object
#  9   content             object
#  10  user_num_posts      int64
#  11  user_reputation     int64
#  12  quoted_post_ids     object
#  13  post_data_creation  object
# dtypes: int64(7), object(7)
# memory usage: 360.4+ MB
# ((3373789, 14), None)

# %%
posts_threads_df = posts_threads_df[~posts_threads_df["content"].isna()].copy()
posts_threads_df.shape, posts_threads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3369015 entries, 0 to 3373788
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   post_id             int64
#  1   site_id             int64
#  2   board_id            int64
#  3   thread_id           int64
#  4   user_id             int64
#  5   site_name           object
#  6   board_title         object
#  7   thread_title        object
#  8   username            object
#  9   content             object
#  10  user_num_posts      int64
#  11  user_reputation     int64
#  12  quoted_post_ids     object
#  13  post_data_creation  object
# dtypes: int64(7), object(7)
# memory usage: 385.6+ MB
# ((3369015, 14), None)

# %%
posts_threads_df
# Out:
#          post_id  site_id  board_id  thread_id  user_id  \
# 0             34       10       114          9     1174
# 1            637       10       114        113     1174
# 2            710       10       114        137     1174
# 3            491       10       114         99     1548
# 4            571       10        46        120     1968
# ...          ...      ...       ...        ...      ...
# 3373784    42116       20        49       8611    24965
# 3373785    42124       20        62       8454    22583
# 3373786    42129       20        62       8454    15407
# 3373787    42134       20        62       8454    25064
# 3373788    42135       20        62       8454    25064
#
#                       site_name              board_title  \
# 0             forum.antichat.ru           Веб-уязвимости
# 1             forum.antichat.ru           Веб-уязвимости
# 2             forum.antichat.ru           Веб-уязвимости
# 3             forum.antichat.ru           Веб-уязвимости
# 4             forum.antichat.ru                 Болталка
# ...                         ...                      ...
# 3373784  torum6uvof666pzw.onion      General Discussions
# 3373785  torum6uvof666pzw.onion  Marketplace Discussions
# 3373786  torum6uvof666pzw.onion  Marketplace Discussions
# 3373787  torum6uvof666pzw.onion  Marketplace Discussions
# 3373788  torum6uvof666pzw.onion  Marketplace Discussions
#
#                                       thread_title          username  \
# 0                                    ВЗЛОМ ФОРУМОВ             Algol
# 1                         Есть вопрос на счёт чата             Algol
# 2                              Клиенты для чата...             Algol
# 3        Всевидящее Око на http://chat.userline.ru  GPT cd-r74xl 24x
# 4                                    Зацените сайт             iRedX
# ...                                            ...               ...
# 3373784                                 Free stuff        tolerance2
# 3373785                                  KEYLOGGER            mrkcuf
# 3373786                                  KEYLOGGER               rIA
# 3373787                                  KEYLOGGER       lovelycloud
# 3373788                                  KEYLOGGER       lovelycloud
#
#                                                    content  user_num_posts  \
# 0            Адрес хоть дай...Первый раз слышу о таком ...            1761
# 1                             Кстати этот чат ломается ...            1761
# 2        Чесно говоря это действительно большая редкост...            1761
# 3        Сорри, этт я неправильно указал ихний адрес. И...               1
# 4                                   Скоро будет обновление             123
# ...                                                    ...             ...
# 3373784  What is that? I dont have javascript enabled s...              14
# 3373785  ***LINK***lovelycloud[./memberlist.php?mode=vi...              52
# 3373786  I wrote some keyloggers for android if you are...              27
# 3373787                                               ok..               7
# 3373788  ***LINK***rIA[./memberlist.php?mode=viewprofil...               7
#
#          user_reputation quoted_post_ids      post_data_creation
# 0                      0              {}  2002-05-31 06:36:00-03
# 1                      0              {}  2002-08-05 16:15:00-03
# 2                      0              {}  2002-08-12 08:08:00-03
# 3                      0              {}  2002-07-19 09:30:00-03
# 4                      9              {}  2002-07-31 23:01:00-03
# ...                  ...             ...                     ...
# 3373784                0              {}  2019-08-06 21:00:00-03
# 3373785                0              {}  2019-08-06 21:00:00-03
# 3373786                0              {}  2019-08-06 21:00:00-03
# 3373787                0              {}  2019-08-06 21:00:00-03
# 3373788                0              {}  2019-08-06 21:00:00-03
#
# [3369015 rows x 14 columns]

# %% [markdown]
# ### Searching content

# %% [markdown]
# #### Searching URI

# %%
uri_reference = "^(?:([A-Za-z][A-Za-z0-9+\\-.]*):(?://((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|:)*@)?(?:\\[(?:(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?|[Vv][0-9A-Fa-f]+\\.(?:[!$&'()*+,;=A-Za-z0-9\\-._~]|:)+)\\]|(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])*)(?::[0-9]*)?)((?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|(/(?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)?)|((?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|())(?:\\?((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?(?:#((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?|(?://((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|:)*@)?(?:\\[(?:(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?|[Vv][0-9A-Fa-f]+\\.(?:[!$&'()*+,;=A-Za-z0-9\\-._~]|:)+)\\]|(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])*)(?::[0-9]*)?)((?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|(/(?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)?)|((?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|@)+(?:/(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])*)*)|())(?:\\?((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?(?:#((?:(?:(?:%[0-9A-Fa-f]{2}|[!$&'()*+,;=A-Za-z0-9\\-._~])|[:@])|[/?])*))?)$"

# %%
posts_threads_df["uris_mentioned"] = posts_threads_df["content"].apply(lambda x: re.findall(uri_reference, x.lower(), flags=re.IGNORECASE))

# %%
posts_threads_df["uris_mentioned_len"] = posts_threads_df["uris_mentioned"].apply(lambda x: len(x))

# %% [markdown]
# #### Searching URL

# %%
url_reference = "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"

# %%
posts_threads_df["urls_mentioned"] = posts_threads_df["content"].apply(lambda x: re.findall(url_reference, x.lower(), flags=re.IGNORECASE))

# %%
posts_threads_df["urls_mentioned_len"] = posts_threads_df["urls_mentioned"].apply(lambda x: len(x))

# %%
posts_threads_df[posts_threads_df["urls_mentioned_len"]>0]
# Out:
#          post_id  site_id  board_id  thread_id  user_id  \
# 3            491       10       114         99     1548
# 6            570       10        46        120     1968
# 8            654       10       114        135     1127
# 15           432       10       114         15      747
# 30          1007       10       114        214      747
# ...          ...      ...       ...        ...      ...
# 3373720    41996       20        49       8530    24603
# 3373730    42015       20        60       7414     4266
# 3373734    42025       20        34       8471    24802
# 3373754    42062       20        25       8629    19569
# 3373763    42093       20        62       8638    24872
#
#                       site_name              board_title  \
# 3             forum.antichat.ru           Веб-уязвимости
# 6             forum.antichat.ru                 Болталка
# 8             forum.antichat.ru           Веб-уязвимости
# 15            forum.antichat.ru           Веб-уязвимости
# 30            forum.antichat.ru           Веб-уязвимости
# ...                         ...                      ...
# 3373720  torum6uvof666pzw.onion      General Discussions
# 3373730  torum6uvof666pzw.onion               Challenges
# 3373734  torum6uvof666pzw.onion              Development
# 3373754  torum6uvof666pzw.onion       Social Engineering
# 3373763  torum6uvof666pzw.onion  Marketplace Discussions
#
#                                               thread_title          username  \
# 3                Всевидящее Око на http://chat.userline.ru  GPT cd-r74xl 24x
# 6                                            Зацените сайт             iRedX
# 8          А тут есть уязвимости? http://banya.nordnet.ru/             12345
# 15                                  Список взломаных чатов         Егорыч+++
# 30                                   Вариант дизайна сайта         Егорыч+++
# ...                                                    ...               ...
# 3373720  I have bank accounts need a hacker for stolen ...           Wittica
# 3373730  Pentesting Walkthrough from a lonely ole scrip...        D1sgruntl3
# 3373734                     PNG Compression - Huffman Tree          Rijndael
# 3373754                               1100 website DB Leak           Sancloi
# 3373763                           NEW FORUM -> CHECK US <-      darknetforum
#
#                                                    content  user_num_posts  \
# 3        Сорри, этт я неправильно указал ихний адрес. И...               1
# 6        Вот мой сайт, на мой взгляд очень полезный.\n*...             123
# 8        ***LINK***http://banya.nordnet.ru/[http://bany...               2
# 15       </span><table border="0" align="center" width=...            1364
# 30       ***LINK***www.0day.ru[http://www.0day.ru]***LI...            1364
# ...                                                    ...             ...
# 3373720  ***LINK***Abhi5363[./memberlist.php?mode=viewp...              11
# 3373730  ***LINK***wfalcon[./memberlist.php?mode=viewpr...            1464
# 3373734  ***LINK***aspire[./memberlist.php?mode=viewpro...               2
# 3373754  Hi guys,\n\nI got the information today, there...               3
# 3373763  ~Wiki\n~Reviews\n~Tutorials\n~Carding\nAnd mor...               1
#
#          user_reputation quoted_post_ids      post_data_creation  \
# 3                      0              {}  2002-07-19 09:30:00-03
# 6                      9              {}  2002-07-31 22:59:00-03
# 8                      0              {}  2002-08-07 20:47:00-03
# 15                    20              {}  2002-07-08 14:37:00-03
# 30                    20              {}  2002-09-19 15:01:00-03
# ...                  ...             ...                     ...
# 3373720                0              {}  2019-08-05 21:00:00-03
# 3373730                0              {}  2019-08-05 21:00:00-03
# 3373734                0              {}  2019-08-06 21:00:00-03
# 3373754                0              {}  2019-08-06 21:00:00-03
# 3373763                0              {}  2019-08-06 21:00:00-03
#
#         ipv4_mentioned  ipv4_mentioned_len  \
# 3                   []                   0
# 6                   []                   0
# 8                   []                   0
# 15                  []                   0
# 30                  []                   0
# ...                ...                 ...
# 3373720             []                   0
# 3373730             []                   0
# 3373734             []                   0
# 3373754             []                   0
# 3373763             []                   0
#
#                                             urls_mentioned  urls_mentioned_len
# 3        [http://chat.userline.ru[http://chat.userline....                   1
# 6        [http://redx.narod.ru[http://redx.narod.ru]***...                   1
# 8        [http://banya.nordnet.ru/[http://banya.nordnet...                   1
# 15       [http://antichat.ru/crackchat/chatlist.xml[htt...                   1
# 30                         [http://www.0day.ru]***link***]                   1
# ...                                                    ...                 ...
# 3373720                    [http://empiremktxgjovhm.onion]                   1
# 3373730  [http://torum6uvof666pzw.onion/viewtopic.php?f...                   1
# 3373734  [http://www.libpng.org/pub/png/apps/pngcheck.h...                   1
# 3373754  [https://www.zataz.com/stockage-pirate-nouvell...                   1
# 3373763                   [http://7ckme3gpbdzmbbtg.onion/]                   1
#
# [506012 rows x 18 columns]

# %% [markdown]
# #### Searching URN

# %%
urn_reference = "^(([^:/?#]+)?:)?(//([^/?#]*))?([^?#]*)(\?([^#]*))?(#(.*))?"
urn_reference = "^((?P<scheme>[^:/?#]+):(?=//))?(//)?(((?P<login>[^:]+)(?::(?P<password>[^@]+)?)?@)?(?P<host>[^@/?#:]*)(?::(?P<port>\d+)?)?)?(?P<path>[^?#]*)(\?(?P<query>[^#]*))?(#(?P<fragment>.*))?"
urn_reference = r'(?:http://|ftp://)?\w+\.\S*[^.\s]'

# %%
posts_threads_df["urns_mentioned"] = posts_threads_df["content"].apply(lambda x: re.findall(urn_reference, x.lower(), flags=re.IGNORECASE))

# %%
posts_threads_df["urns_mentioned_len"] = posts_threads_df["urns_mentioned"].apply(lambda x: len(x))

# %% [markdown]
# #### Searching Ipv4

# %%
ipv4_address = '^(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])$'

# %%
posts_threads_df["ipv4_mentioned"] = posts_threads_df["content"].apply(lambda x: re.findall(ipv4_address, x.lower(), flags=re.IGNORECASE))

# %%
posts_threads_df["ipv4_mentioned_len"] = posts_threads_df["ipv4_mentioned"].apply(lambda x: len(x))

# %%
posts_threads_df[posts_threads_df["ipv4_mentioned_len"]>0]
# Out:
#          post_id  site_id  board_id  thread_id    user_id  \
# 391740    677196       10        46      69373      37919
# 486347    838462       10        46      74541      52440
# 589390   1027575       10        46      98915      39265
# 849246   1487719       10        46     138102      54178
# 1011159  1810671       10        46     169077      68970
# 1087586  1961320       10        46     182596      52440
# 1259508  2271006       10        13     220020     122018
# 1299212  2332905       10       122     119485      57738
# 1299231  2332909       10       122     119485      37694
# 1440714  2546535       10        46     258083     140776
# 1474637  2598166       10        46     264769     103873
# 1656184  2876565       10        46     300142     174439
# 1656623  2877268       10        46     258083     158079
# 1656754  2877440       10        46     258083     140776
# 1683759  2918946       10        46     305698      47106
# 1754165  3024518       10        23     319203     174152
# 1777336  3059843       10        37     323265      57557
# 2177172  3749574       10       113     398971     194216
# 2262793  3916797       10       113     398971     276756
# 2385025  4129579       10       145     262867     309393
# 2774893     1061       12         2        402        548
# 2854227   122299       12        18      20998  121317951
# 3370123    36289       20        26       7127      21747
# 3370391    36661       20        26       7127       3344
#
#                       site_name                               board_title  \
# 391740        forum.antichat.ru                                  Болталка
# 486347        forum.antichat.ru                                  Болталка
# 589390        forum.antichat.ru                                  Болталка
# 849246        forum.antichat.ru                                  Болталка
# 1011159       forum.antichat.ru                                  Болталка
# 1087586       forum.antichat.ru                                  Болталка
# 1259508       forum.antichat.ru       Skype, IRC, ICQ, Jabber и другие IM
# 1299212       forum.antichat.ru                            Новости форума
# 1299231       forum.antichat.ru                            Новости форума
# 1440714       forum.antichat.ru                                  Болталка
# 1474637       forum.antichat.ru                                  Болталка
# 1656184       forum.antichat.ru                                  Болталка
# 1656623       forum.antichat.ru                                  Болталка
# 1656754       forum.antichat.ru                                  Болталка
# 1683759       forum.antichat.ru                                  Болталка
# 1754165       forum.antichat.ru              Мировые новости. Обсуждения.
# 1777336       forum.antichat.ru              PHP, PERL, MySQL, JavaScript
# 2177172       forum.antichat.ru  Беспроводные технологии/Wi-Fi/Wardriving
# 2262793       forum.antichat.ru  Беспроводные технологии/Wi-Fi/Wardriving
# 2385025       forum.antichat.ru                       Хостинги - Hostings
# 2774893          raidforums.com                        Raiding Discussion
# 2854227          raidforums.com                                The Lounge
# 3370123  torum6uvof666pzw.onion                         Denial of Service
# 3370391  torum6uvof666pzw.onion                         Denial of Service
#
#                                               thread_title          username  \
# 391740                ++Диапазоны Ip крупных провайдеров++            m9chik
# 486347                                             ачат КС   Godfather Bulan
# 589390                      дайте быстренькую проксю. элит           nonamez
# 849246                                           ip google           Nelzone
# 1011159                                           вопросик            Explay
# 1087586          CS source Античат (Да да. Это вам не 1.6)   Godfather Bulan
# 1259508                                            сервера         Spiderman
# 1299212  Вопрос. Кому ночью приходило письмо с темой *А...         crackmail
# 1299231  Вопрос. Кому ночью приходило письмо с темой *А...            svesve
# 1440714                         Что у вас в буфере обмена?          C00LPack
# 1474637                             не работает файл hosts       cheater_man
# 1656184             Вы видите цветные сны или черно-белые?       Street King
# 1656623                         Что у вас в буфере обмена?         ChernoHod
# 1656754                         Что у вас в буфере обмена?          C00LPack
# 1683759                                             NOD 32       Alexandr II
# 1754165  Google: мы создали самый большой в мире DNS-се...             \/ITA
# 1777336        Не могу законнектиться на удаленный сервер.             Chaak
# 2177172                                  прога Router Scan             TOX1C
# 2262793                                  прога Router Scan        andrey_kem
# 2385025                                     определение IP       respectmind
# 2774893                             BLACK STREAMER W/ LISP  Anonymous_Fapper
# 2854227                               Post your "Ctrl + V"              John
# 3370123               Are you a DDOS expert? Come show me!          SNOOPEPE
# 3370391               Are you a DDOS expert? Come show me!      Registraxion
#
#                 content  user_num_posts  user_reputation quoted_post_ids  \
# 391740    255.255.255.0              79               -5              {}
# 486347     89.207.67.77             264               25              {}
# 589390        127.0.0.1             994               17              {}
# 849246   216.239.59.104             207                6              {}
# 1011159    10.50.10.238               3                0              {}
# 1087586   89.207.69.149             264               25              {}
# 1259508       127.0.0.1               5                0              {}
# 1299212    82.147.70.18             181               10              {}
# 1299231    82.147.70.18             613               11              {}
# 1440714    187.51.64.98             472               19              {}
# 1474637       127.0.0.1             685                7              {}
# 1656184  82.145.208.225               7                0              {}
# 1656623   212.16.203.28              10                0              {}
# 1656754    62.84.16.138             472               19              {}
# 1683759       4.2.67.10            1189               87              {}
# 1754165         8.8.8.8              48                8              {}
# 1777336       127.0.0.1            1236               80              {}
# 2177172  195.135.199.24             733               17              {}
# 2262793     192.168.1.1               6                0              {}
# 2385025  212.152.36.238               8                0              {}
# 2774893   73.34.197.214               4                0              {}
# 2854227   168.216.12.81             980             1475              {}
# 3370123    104.28.4.133              11                0              {}
# 3370391   223.63.222.89              21                0              {}
#
#              post_data_creation    ipv4_mentioned  ipv4_mentioned_len  \
# 391740   2008-05-04 16:54:00-03   [255.255.255.0]                   1
# 486347   2008-08-28 19:19:00-03    [89.207.67.77]                   1
# 589390   2008-12-31 17:53:00-02       [127.0.0.1]                   1
# 849246   2009-08-29 09:09:00-03  [216.239.59.104]                   1
# 1011159  2010-01-07 18:32:00-02    [10.50.10.238]                   1
# 1087586  2010-03-07 13:17:00-03   [89.207.69.149]                   1
# 1259508  2010-07-27 10:51:00-03       [127.0.0.1]                   1
# 1299212  2010-09-05 18:14:00-03    [82.147.70.18]                   1
# 1299231  2010-09-05 18:17:00-03    [82.147.70.18]                   1
# 1440714  2011-02-08 16:54:00-02    [187.51.64.98]                   1
# 1474637  2011-03-16 14:07:00-03       [127.0.0.1]                   1
# 1656184  2011-10-26 13:08:00-02  [82.145.208.225]                   1
# 1656623  2011-10-27 03:30:00-02   [212.16.203.28]                   1
# 1656754  2011-10-27 09:11:00-02    [62.84.16.138]                   1
# 1683759  2011-11-28 18:49:00-02       [4.2.67.10]                   1
# 1754165  2012-02-16 05:37:00-02         [8.8.8.8]                   1
# 1777336  2012-03-11 20:22:00-03       [127.0.0.1]                   1
# 2177172  2014-08-01 19:16:00-03  [195.135.199.24]                   1
# 2262793  2015-11-17 19:13:00-02     [192.168.1.1]                   1
# 2385025  2017-09-18 14:32:00-03  [212.152.36.238]                   1
# 2774893  2015-03-23 03:54:00-03   [73.34.197.214]                   1
# 2854227  2017-05-17 11:29:00-03   [168.216.12.81]                   1
# 3370123  2019-07-19 21:00:00-03    [104.28.4.133]                   1
# 3370391  2019-07-21 21:00:00-03   [223.63.222.89]                   1
#
#         urls_mentioned  urls_mentioned_len
# 391740              []                   0
# 486347              []                   0
# 589390              []                   0
# 849246              []                   0
# 1011159             []                   0
# 1087586             []                   0
# 1259508             []                   0
# 1299212             []                   0
# 1299231             []                   0
# 1440714             []                   0
# 1474637             []                   0
# 1656184             []                   0
# 1656623             []                   0
# 1656754             []                   0
# 1683759             []                   0
# 1754165             []                   0
# 1777336             []                   0
# 2177172             []                   0
# 2262793             []                   0
# 2385025             []                   0
# 2774893             []                   0
# 2854227             []                   0
# 3370123             []                   0
# 3370391             []                   0

# %% [markdown]
# #### Searching Ipv6

# %%
ipv6_address = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)$'
ipv6_addrz = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+$'
ipv6_address_or_addrz = '^(?:(?:[0-9A-Fa-f]{1,4}:){6}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|::(?:[0-9A-Fa-f]{1,4}:){5}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){4}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){3}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,2}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:){2}(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,3}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}:(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,4}[0-9A-Fa-f]{1,4})?::(?:[0-9A-Fa-f]{1,4}:[0-9A-Fa-f]{1,4}|(?:(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5])\\.){3}(?:[0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]|25[0-5]))|(?:(?:[0-9A-Fa-f]{1,4}:){,5}[0-9A-Fa-f]{1,4})?::[0-9A-Fa-f]{1,4}|(?:(?:[0-9A-Fa-f]{1,4}:){,6}[0-9A-Fa-f]{1,4})?::)(?:%25(?:[A-Za-z0-9\\-._~]|%[0-9A-Fa-f]{2})+)?$'

# %%
posts_threads_df["ipv6_mentioned"] = posts_threads_df["content"].apply(lambda x: re.findall(ipv6_address_or_addrz, x.lower(), flags=re.IGNORECASE))

# %%
posts_threads_df["ipv6_mentioned_len"] = posts_threads_df["ipv6_mentioned"].apply(lambda x: len(x))

# %% [markdown]
# ### Word References

# %% [markdown]
# #### Siemens references

# %%
keywords=["siemens", "siemens s7", "simatic s7", "s7", "simatic"]

pattern = '|'.join(keywords)

# %%
siemens_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
siemens_df.info(), siemens_df.shape, siemens_df.iloc[0,:]

# %%
siemens_content = ' '.join(siemens_df["content"])

# %%
siemens_dict = get_words_frequency(siemens_content)
len(siemens_dict)

# %%
showWordCloud(siemens_dict, f"Siemens-Wordcloud", max_words=int(len(siemens_dict)))

# %% [markdown]
# #### Port references

# %%
keywords=["port102", "port:102", "bacnet"]

pattern = '|'.join(keywords)

# %%
port102_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
port102_df.info(), port102_df.shape, port102_df.iloc[0,:]

# %%
port102_content = ' '.join(port102_df["content"])

# %%
port102_dict = get_words_frequency(port102_content)
len(port102_dict)

# %%
showWordCloud(port102_dict, "Port:102-Wordcloud", max_words=int(len(port102_dict)))

# %% [markdown]
# #### CVSS references

# %%
keywords=["cvss"]

pattern = '|'.join(keywords)

# %%
cvss_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
cvss_df.info(), cvss_df.shape, cvss_df.iloc[0,:]

# %%
cvss_content = ' '.join(cvss_df["content"])

# %%
cvss_dict = get_words_frequency(cvss_content)
len(cvss_dict)

# %%
showWordCloud(cvss_dict, f"CVSS-Wordcloud", max_words=int(len(cvss_dict)))

# %% [markdown]
# #### EPSS references

# %%
keywords=["epss"]

pattern = '|'.join(keywords)

# %%
epss_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
epss_df.info(), epss_df.shape, epss_df.iloc[0,:]

# %%
epss_content = ' '.join(epss_df["content"])

# %%
epss_dict = get_words_frequency(epss_content)
len(epss_dict)

# %%
showWordCloud(epss_dict, f"EPSS-Wordcloud", max_words=int(len(epss_dict)))

# %% [markdown]
# #### FUD references

# %%
keywords=["fud"]

pattern = '|'.join(keywords)

# %%
fud_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
fud_df.info(), fud_df.shape, fud_df.iloc[0,:]

# %%
fud_content = ' '.join(fud_df["content"])

# %%
fud_dict = get_words_frequency(fud_content)
len(fud_dict)

# %%
showWordCloud(fud_dict, f"FUD-Wordcloud", max_words=int(len(fud_dict)))

# %% [markdown]
# #### SHODAN references

# %%
keywords=["shodan"]

pattern = '|'.join(keywords)

# %%
shodan_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
shodan_df.info(), shodan_df.shape, shodan_df.iloc[0,:]

# %%
shodan_content = ' '.join(shodan_df["content"])

# %%
shodan_dict = get_words_frequency(shodan_content)
len(shodan_dict)

# %%
shodan_dict

# %%
showWordCloud(shodan_dict, "SHODAN-Wordcloud", max_words=int(len(shodan_dict)))

# %% [markdown]
# #### COVID References

# %%
keywords=["covid", "covid19", "covid-19", "sars", "sars-cov-2", "sars-cov"]

pattern = '|'.join(keywords)

# %%
covid_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
covid_df.info(), covid_df.shape, covid_df.iloc[0,:]

# %%
covid_content = ' '.join(covid_df["content"])

# %%
covid_dict = get_words_frequency(covid_content)
len(covid_dict)

# %%
showWordCloud(covid_dict, "COVID-Wordcloud", max_words=int(len(covid_dict)))

# %% [markdown]
# #### CVE references

# %%
keywords=["cve"]

pattern = '|'.join(keywords)

# %%
cve_df = posts_threads_df[posts_threads_df["content"].str.lower().str.contains(pattern)]
cve_df.info(), cve_df.shape, cve_df.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1479 entries, 867 to 3371804
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   post_id             1479 non-null   int64
#  1   site_id             1479 non-null   int64
#  2   board_id            1479 non-null   int64
#  3   thread_id           1479 non-null   int64
#  4   user_id             1479 non-null   int64
#  5   site_name           1479 non-null   object
#  6   board_title         1479 non-null   object
#  7   thread_title        1479 non-null   object
#  8   username            1479 non-null   object
#  9   content             1479 non-null   object
#  10  user_num_posts      1479 non-null   int64
#  11  user_reputation     1479 non-null   int64
#  12  quoted_post_ids     1479 non-null   object
#  13  post_data_creation  1479 non-null   object
#  14  ipv4_mentioned      1479 non-null   object
#  15  ipv4_mentioned_len  1479 non-null   int64
# dtypes: int64(8), object(8)
# memory usage: 196.4+ KB
# (None,
#  (1479, 16),
#  post_id                                                            1166
#  site_id                                                              10
#  board_id                                                            114
#  thread_id                                                           246
#  user_id                                                            1371
#  site_name                                             forum.antichat.ru
#  board_title                                              Веб-уязвимости
#  thread_title                                     Ne ponil!!!!!!!!!!!!&#
#  username                                                   Dj Skeleton™
#  content               </span><table border="0" align="center" width=...
#  user_num_posts                                                      224
#  user_reputation                                                       1
#  quoted_post_ids                                                      {}
#  post_data_creation                               2002-10-13 10:18:00-03
#  ipv4_mentioned                                                       []
#  ipv4_mentioned_len                                                    0
#  Name: 867, dtype: object)

# %%
# cve_df["content"] = cve_df["content"].apply(lambda x: re.sub('[0-9]+', "", x) )
cve_content = ' '.join(cve_df["content"])

# %%
cve_dict = get_words_frequency(cve_content)
len(cve_dict)
# Out:
# 92175

# %%
showWordCloud(covid_dict, "CVE-Wordcloud", max_words=int(len(cve_dict)))

# %% [markdown]
# #### Focus on CVE

# %%
cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve[-]?[0-9]*[-]?[0-9]*)', x.lower(), flags=re.IGNORECASE) )
# Out:
# /tmp/ipykernel_870963/1975460517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cve_df["cve_codes"] = cve_df["content"].apply(lambda x: re.findall(r'(cve[-]?[0-9]*[-]?[0-9]*)', x.lower(), flags=re.IGNORECASE) )

# %%
cve_df["cve_codes"]
# Out:
# 867                             [cve]
# 875                             [cve]
# 16612                           [cve]
# 23812                           [cve]
# 27221                      [cve, cve]
#                       ...
# 3371011                         [cve]
# 3371030                         [cve]
# 3371168                         [cve]
# 3371200                    [cve, cve]
# 3371804    [cve, cve, cve-2019-13478]
# Name: cve_codes, Length: 1479, dtype: object

# %%
import itertools
list(set(list(itertools.chain(*cve_df["cve_codes"].values.tolist()))))
# Out:
# ['cve-2017-1099',
#  'cve-2007-1863',
#  'cve-2011-2202',
#  'cve-2019-13720',
#  'cve-2000-0992',
#  'cve-2004-2763',
#  'cve-2013-0322',
#  'cve-2014-2719',
#  'cve-2009-2416',
#  'cve2',
#  'cve-2011-4885',
#  'cve-2012-3135',
#  'cve-2012-1737',
#  'cve-2007-4749',
#  'cve-2012-0031',
#  'cve-2014-5207',
#  'cve-2018-5726',
#  'cve5',
#  'cve-2012-5359',
#  'cve-2016-8704',
#  'cve-2008-5353',
#  'cve-2018-20685',
#  'cve-2008-1334',
#  'cve1',
#  'cve-2015-2676',
#  'cve-2004-2761',
#  'cve-2017-13086',
#  'cve-2018-10562',
#  'cve-2018-5725',
#  'cve-2009-0238',
#  'cve-2015-4495',
#  'cve-2016-5833',
#  'cve-2017-1000251',
#  'cve-2010-1205',
#  'cve-2019-3568',
#  'cve-2012-3499',
#  'cve4',
#  'cve-2017-3169',
#  'cve-2014-0118',
#  'cve-2015-1318',
#  'cve-2012-5360',
#  'cve-2016-2344',
#  'cve2015-5122',
#  'cve-2006-4683',
#  'cve-2010-1452',
#  'cve-2013-5058',
#  'cve-2010-0886',
#  'cve-2011-2777',
#  'cve-2011-0628',
#  'cve-2014-5119',
#  'cve-2016-6663',
#  'cve-2016-7168',
#  'cve-2007-5000',
#  'cve-2016-9081',
#  'cve-2016-0701',
#  'cve-2015-5622',
#  'cve3',
#  'cve-2009-1956',
#  'cve-2017-8570',
#  'cve-2015-1701',
#  'cve-2016-0777',
#  'cve-2015-1427',
#  'cve-2017-14315',
#  'cve-2012-2856',
#  'cve-2013-1763',
#  'cve-1999-0455',
#  'cve-2012-3287',
#  'cve-2012-0158',
#  'cve-2011-4109',
#  'cve-2016-2222',
#  'cve-2015-3105',
#  'cve-2008-0405',
#  'cve-2016-1531',
#  'cve-2017-13078',
#  'cve-2016-10033',
#  'cve-2018-10561',
#  'cve-2010-1623',
#  'cve-2013-209',
#  'cve-2017-0782',
#  'cve-2007-5225',
#  'cve30',
#  'cve-2010-2020',
#  'cve-2012-5611',
#  'cve-2014-0300',
#  'cve-2011-0096',
#  'cve-2014-1776',
#  'cve-2015-1328',
#  'cve-2015-3036',
#  'cve-2010-1885',
#  'cve-2015-3202',
#  'cve-2017-7692',
#  'cve-2012-0027',
#  'cve-2013-6117',
#  'cve-2018-6213',
#  'cve-2011-1266',
#  'cve-2008-7253',
#  'cve-2012-6422',
#  'cve-2015-4566',
#  'cve-2017-7235',
#  'cve2011-3368',
#  'cve-2012-0217',
#  'cve-2019-3462',
#  'cve-2016-0051',
#  'cve-2015-73589',
#  'cve-2012-',
#  'cve-2016-1564',
#  'cve-2017-14243',
#  'cve-2013-1280',
#  'cve-2018-4407',
#  'cve-2012-1747',
#  'cve-2015-2445',
#  'cve-2014-0231',
#  'cve-2012-2863',
#  'cve-2014-0098',
#  'cve-2019-1988',
#  'cve-2007-0069',
#  'cve-2015-5122',
#  'cve-2015-5734',
#  'cve-2012-4681',
#  'cve-2014-4079',
#  'cve-2010-0806',
#  'cve-2015-5733',
#  'cve-2015-8562',
#  'cve-2009-0360',
#  'cve-2013-6438',
#  'cve-2017-5892',
#  'cve-2006-4842',
#  'cve-2015-5730',
#  'cve-2017-0262',
#  'cve-2018-20684',
#  'cve-2007-3008',
#  'cve-2008-3475',
#  'cve59',
#  'cve-2017-0199',
#  'cve-2014-1767',
#  'cve-2014-1814',
#  'cve-2017-0781',
#  'cve2014-8877',
#  'cve-2017-13082',
#  'cve-2011-3607',
#  'cve-2012-1528',
#  'cve-2016-6635',
#  'cve-2019-1069',
#  'cve-2009-1337',
#  'cve-2017-5638',
#  'cve-2012-0946',
#  'cve-2016-6634',
#  'cve-2012-3524',
#  'cve-2013-2171',
#  'cve2010-2861',
#  'cve-',
#  'cve-2008-2540',
#  'cve-2008-4250',
#  'cve7',
#  'cve-2009-3129',
#  'cve-2016-7169',
#  'cve-2010-1146',
#  'cve-2017-13079',
#  'cve-2010-4258',
#  'cve-2011-3402',
#  'cve-2008-0409',
#  'cve-2008-2938',
#  'cve-2016-5387',
#  'cve2012-1723',
#  'cve-2012-0056',
#  'cve-2011-0038',
#  'cve-2012-2851',
#  'cve-2015-1863',
#  'cve-2004-2320',
#  'cve-2013-0640',
#  'cve48',
#  'cve-2014-3694',
#  'cve-2012-2226',
#  'cve-2008-0010',
#  'cve-2013-3906',
#  'cve-2013-0871',
#  'cve-2013-6040',
#  'cve-2018-6789',
#  'cve-2012-6470',
#  'cve-2001-0323',
#  'cve-2018-9206',
#  'cve-2017-3135',
#  'cve-2011-0611',
#  'cve-2010-1297',
#  'cve-2017-1000250',
#  'cve-2017-13080',
#  'cve-2012-1678',
#  'cve-2015-1635',
#  'cve-2009-2692',
#  'cve-2010-2188',
#  'cve-2012-1720',
#  'cve-2018-0491',
#  'cve-2014-9583',
#  'cve-2008-2992',
#  'cve80',
#  'cve-2013-1858',
#  'cve-2011-1964',
#  'cve-2011-2505',
#  'cve2006-3392',
#  'cve-2015-5715',
#  'cve2013-7091',
#  'cve-2014-9033',
#  'cve-2017-5753',
#  'cve-2014-6278',
#  'cve85',
#  'cve-2013-4854',
#  'cve-2013-1892',
#  'cve-2013-1294',
#  'cve-2018-1999002',
#  'cve2012-2122',
#  'cve-2011-2506',
#  'cve-2016-5239',
#  'cve-2017-5754',
#  'cve2011-3192',
#  'cve-2016-8706',
#  'cve-2015-8370',
#  'cve-2016-6662',
#  'cve-2007-2446',
#  'cve-2016-8612',
#  'cve-2012-1713',
#  'cve-2012-4969',
#  'cve-2018-20782',
#  'cve-2016-4975',
#  'cve-2000-0538',
#  'cve-2009-1890',
#  'cve-2010-3081',
#  'cve-2016-0728',
#  'cve-2007-6420',
#  'cve-2015-7989',
#  'cve-2008-0661',
#  'cve-2015-0311',
#  'cve-2012-4025',
#  'cve-2012-2687',
#  'cve75',
#  'cve-2010-3346',
#  'cve-2019-11707',
#  'cve-2017-0213',
#  'cve-2017-5715',
#  'cve-2005-3398',
#  'cve-2011-4619',
#  'cve-2012-5667',
#  'cve-2013-2551',
#  'cve-2013-1862',
#  'cve-2015-8565',
#  'cve-2014-3704',
#  'cve-2003-1418',
#  'cve-2010-4347',
#  'cve-2015-2419',
#  'cve-2016-4566',
#  'cve-2011-4108',
#  'cve-2012-0831',
#  'cve-2011-1485',
#  'cve-2010-3972',
#  'cve-2015-7359',
#  'cve-2015-8446',
#  'cve-2010-0188',
#  'cve-2009-2284',
#  'cve-2006-0003',
#  'cve145',
#  'cve6',
#  'cve-2015-3429',
#  'cve-2013-1347',
#  'cve2010-4221',
#  'cve-2017-14803',
#  'cve-2012-5692',
#  'cve-2011-4969',
#  'cve-2017-0263',
#  'cve-2009-2823',
#  'cve-2009-3547',
#  'cve-2010-0386',
#  'cve-2013-2249',
#  'cve-2017-7494',
#  'cve-2010-3881',
#  'cve-2008-0081',
#  'cve-2015-5397',
#  'cve30360',
#  'cve-2013-0074',
#  'cve-2011-4576',
#  'cve-2009-1195',
#  'cve-2019-13721',
#  'cve-2014-6271',
#  'cve-2019-6109',
#  'cve-2015-2652',
#  'cve-2013-0156',
#  'cve-2012-3120',
#  'cve-2015-2213',
#  'cve-2015-1862',
#  'cve-2019-10149',
#  'cve-2009-1527',
#  'cve-2015-1815',
#  'cve-2016-1000246',
#  'cve-2014-3695',
#  'cve-2011-3544',
#  'cve-2017-13081',
#  'cve-2012-1718',
#  'cve2011-1720',
#  'cve-2017-9479',
#  'cve-2007-1374',
#  'cve2013-0156',
#  'cve-2010-4077',
#  'cve-2010-2959',
#  'cve-2008-2364',
#  'cve-2014-4014',
#  'cve-2012-1535',
#  'cve-2009-2265',
#  'cve-2018-10676',
#  'cve-2010-3179',
#  'cve-2015-7254',
#  'cve-2010-4170',
#  'cve-2012-2619',
#  'cve-2013-7236',
#  'cve-2012-1670',
#  'cve-2011-4123',
#  'cve-2011-1261',
#  'cve-2008-0410',
#  'cve-2018-0490',
#  'cve-2018-12019',
#  'cve-2012-1527',
#  'cve-2017-13077',
#  'cve-2018-14847',
#  'cve-2013-3893',
#  'cve-2019-16759',
#  'cve-2014-6332',
#  'cve-2017-6549',
#  'cve-2014-0476',
#  'cve-2011-1262',
#  'cve-2016-2324',
#  'cve8',
#  'cve-2015-3043',
#  'cve-2016-5195',
#  'cve',
#  'cve-2007-6421',
#  'cve-2009-3527',
#  'cve-2017-9788',
#  'cve-2017-13087',
#  'cve-2018-5723',
#  'cve-2019-5869',
#  'cve-2009-2935',
#  'cve-2008-4210',
#  'cve-2016-5093',
#  'cve-2019-11043',
#  'cve-2019-1003000',
#  'cve-2015-8660',
#  'cve-2008-1447',
#  'cve-2016-0778',
#  'cve-2015-3306',
#  'cve2010-4344',
#  'cve-2018-1069',
#  'cve-2014-0226',
#  'cve-2012-2862',
#  'cve-2018-1305',
#  'cve-2002-0902',
#  'cve-2012-1745',
#  'cve-2011-1991',
#  'cve-2012-0782',
#  'cve-2019-6340',
#  'cve-2008-0009',
#  'cve-2001-0653',
#  'cve-2007-6422',
#  'cve-2011-4577',
#  'cve-2011-1127',
#  'cve-2014-3153',
#  'cve-2016-8705',
#  'cve-2009-3867',
#  'cve-2010-3849',
#  'cve-2013-5704',
#  'cve-2014-0497',
#  'cve-2007-1395',
#  'cve-2009-1151',
#  'cve-2011-1963',
#  'cve-2017-0785',
#  'cve-2015-7859',
#  'cve-2011-1984',
#  'cve-2015-8563',
#  'cve-2013-0268',
#  'cve-2013-2049',
#  'cve-2010-0408',
#  'cve-2015-5608',
#  'cve-2009-1046',
#  'cve-2017-16944',
#  'cve-2016-3081',
#  'cve-2012-0779',
#  'cve-2016-5837',
#  'cve-2011-4899',
#  'cve-2011-2110',
#  'cve-2012-0883',
#  'cve-2017-7668',
#  'cve-2008-2271',
#  'cve-2012-2855',
#  'cve-2012-0002',
#  'cve-2011-4130',
#  'cve-2015-7857',
#  'cve-2016-2561',
#  'cve-2016-2315',
#  'cve-2015-5714',
#  'cve-2017-0783',
#  'cve-2009-2698',
#  'cve-2010-0840',
#  'cve-2008-2939',
#  'cve2014-2129',
#  'cve-201',
#  'cve-2009-1955',
#  'cve2013-6786',
#  'cve2017-8917',
#  'cve-2012-0500',
#  'cve-2012-0053',
#  'cve-2014-3696',
#  'cve0',
#  'cve-2015-2331',
#  'cve-2014-0196',
#  'cve66',
#  'cve-2012-1180',
#  'cve-2010-4210',
#  'cve-2008-5736',
#  'cve-2013-1896',
#  'cve2014-2127',
#  'cve-2010-0832',
#  'cve-2011-4317',
#  'cve-2009-3560',
#  'cve-2014-016008',
#  'cve-2014-2803',
#  'cve-2011-2749',
#  'cve-2013-3993',
#  'cve-2009-0007',
#  'cve-2018-12356',
#  'cve-1999-0024',
#  'cve2015-1427',
#  'cve-2017-17215',
#  'cve-2014-0502',
#  'cve-2014-0133',
#  'cve-2010-3850',
#  'cve-2011-2131',
#  'cve-2008-0408',
#  'cve-2012-1746',
#  'cve-2019-6110',
#  'cve-2015-7358',
#  'cve-2010-3301',
#  'cve-2018-4010',
#  'cve-2009-1891',
#  'cve-2018-13849',
#  'cve-2017-6975',
#  'cve-2009-3095',
#  'cve-2017-9542',
#  'cve2015-1635',
#  'cve-2014-0185',
#  'cve-2012-2376',
#  'cve-2010-3847',
#  'cve-2009-1185',
#  'cve-2017-9798',
#  'cve-2016-5835',
#  'cve-2017-13088',
#  'cve-2007-3847',
#  'cve-2003-0352',
#  'cve-2014-1999',
#  'cve-2010-4452',
#  'cve-20',
#  'cve-2015-8709',
#  'cve-2008-0456',
#  'cve-2010-2729',
#  'cve-2014-0160',
#  'cve-2018-7600',
#  'cve-2010-2961',
#  'cve-2015-7835',
#  'cve-2015-1325',
#  'cve2012-1823',
#  'cve-2010-2693',
#  'cve-2011-4122',
#  'cve-2012-1717',
#  'cve-2013-1453',
#  'cve-2017-13084',
#  'cve-2014-1761',
#  'cve-2018-16865',
#  'cve-2013-2094',
#  'cve-2009-1894',
#  'cve-2012-0003',
#  'cve-2017-7679',
#  'cve-2015-3183',
#  'cve-2017-8628',
#  'cve-2011-3192',
#  'cve-2016-4029',
#  'cve-2009-2629',
#  'cve-2017-15906',
#  'cve-2019-6111',
#  'cve-2011-3414',
#  'cve-2011-5054',
#  'cve-2017-12149',
#  'cve-2015-7755',
#  'cve-2006-5752',
#  'cve-2016-3168',
#  'cve-2',
#  'cve-2009-2412',
#  'cve-2013-6462',
#  'cve-2012-0809',
#  'cve-2014-1912',
#  'cve-2011-2748',
#  'cve-2016-1000245',
#  'cve-2018-3952',
#  'cve-2016-9838',
#  'cve2009-3103',
#  'cve-2016-5834',
#  'cve-2011-4313',
#  'cve-2007-6388',
#  'cve-2017-7529',
#  'cve-2013-2465',
#  'cve-2011-4124',
#  'cve-2015-7645',
#  'cve-2016-2221',
#  'cve-2013-0741',
#  'cve-2005-1294',
#  'cve-2017-8295',
#  'cve-2016-2183',
#  'cve-2012-1823',
#  'cve-2017-11882',
#  'cve-2014-3698',
#  'cve2011-1345',
#  'cve2017-5689',
#  'cve262',
#  'cve-2013-0422',
#  'cve-2015-3035',
#  'cve-2015-5623',
#  'cve2014-2126',
#  'cve-2006-3747',
#  'cve-2018-10169',
#  'cve-2011-4062',
#  'cve-2017-3167',
#  'cve-2015-5732',
#  'cve-2018-16866',
#  'cve-2009-2908',
#  'cve-2011-3368',
#  'cve-2019-1987',
#  'cve-2009-1381',
#  'cve-2012-4244',
#  'cve-2017-17562',
#  'cve-2007-6203',
#  'cve-2007-3304',
#  'cve-2011-3389',
#  'cve-2008-3531',
#  'cve-2010-2883',
#  'cve-2018-5724',
#  'cve-2016-8858',
#  'cve-2012-1875',
#  'cve-2010-4073',
#  'cve-2018-16864',
#  'cve-2013-2028',
#  'cve-2013-2566',
#  'cve-2000-0057',
#  'cve-2008-0166',
#  'cve-2007-3855',
#  'cve-2014-0038',
#  'cve-2017-7269',
#  'cve-2011-0035',
#  'cve-2016-6313',
#  'cve-2017-10271',
#  'cve-2010-0249',
#  'cve-2015-6055',
#  'cve-2010-3333',
#  'cve-2019-1986',
#  'cve-2011-4862',
#  'cve-2015-3113',
#  'cve-2015-1538',
#  'cve-2009-3733',
#  'cve-2019-13478',
#  'cve-2018-9995',
#  'cve-2012-1724',
#  'cve-2012-0152',
#  'cve-2011-1256',
#  'cve-2015-3902',
#  'cve-2015-3224',
#  'cve-2015-3864',
#  'cve2009-3960',
#  'cve2014-2128',
#  'cve-2017-14596',
#  'cve2004-2687',
#  'cve2017-5638',
#  'cve-2012-4558',
#  'cve-2006-0063',
#  'cve-2017-7526',
#  'cve-2014-3697',
#  'cve-2010-0094',
#  'cve-2014-4377',
#  'cve-2014-3566',
#  'cve-2010-4221',
#  'cve-2010-3055',
#  'cve2017-1001000',
#  'cve-2016-5734',
#  'cve-2015-5119',
#  'cve-2015-1579',
#  'cve-2013-1773',
#  'cve-2017-16943',
#  'cve-2009-3720',
#  'cve-2008-4609',
#  'cve-2008-0406',
#  'cve-2019-10842',
#  'cve9',
#  'cve-2012-1889',
#  'cve-2013-1443',
#  'cve-2012-0507',
#  'cve-2012-1723',
#  'cve-2009-0023',
#  'cve-2010-3904',
#  'cve-2007-0071',
#  'cve-2014-0318',
#  'cve-2013-2912',
#  'cve-2006-1359',
#  'cve-2010-0434',
#  'cve-2008-',
#  'cve-2011-4898',
#  'cve-2014-9222',
#  'cve-2016-6277',
#  'cve-2012-4024',
#  'cve-2009-3094',
#  'cve-2013-1493',
#  'cve99',
#  'cve-2009-4146',
#  'cve-2009-3555',
#  'cve-1999-0504',
#  'cve-2016-4567',
#  'cve-2018-12020',
#  'cve-2016-10045',
#  'cve-2014-9034',
#  'cve-2011-0094',
#  'cve2011-1764',
#  'cve-2015-7547',
#  'cve-2012-6081',
#  'cve-2014-0322',
#  'cve-2012-5361',
#  'cve-2016-9837',
#  'cve-2013-2423',
#  'cve-2018-0171',
#  'cve-2008-0407',
#  'cve-2019-0708',
#  'cve-2007-4560',
#  'cve-2014-4113',
#  'cve-2014-0224',
#  'cve-2012-1803',
#  'cve-2012-3125',
#  'cve-2013-2224',
#  'cve-2013-5211',
#  'cve-2018-1038',
#  'cve-2010-2568',
#  'cve-2017-0359',
#  'cve-2012-1182',
#  'cve-2011-0419',
#  'cve2011-0094',
#  'cve-2010-3856',
#  'cve-2012-2122',
#  'cve-2014-4877',
#  'cve2010-0738',
#  'cve-2008-0005',
#  'cve-2016-8743',
#  'cve-2010-3848',
#  'cve-2012-0180',
#  'cve-2018-10933',
#  'cve-2017-12611']

# %%
len(list(set(list(itertools.chain(*cve_df["cve_codes"].values.tolist())))))
# Out:
# 654

# %%
df__ = pd.read_csv("../data/CVE_info.csv", sep=",", low_memory=False, encoding="ISO-8859-1")
df__
